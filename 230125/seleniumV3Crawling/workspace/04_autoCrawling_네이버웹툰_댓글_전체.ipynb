# %%
import warnings
warnings.filterwarnings(action='ignore')
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# %%
option = Options()
option.add_argument('--window-size=1000,1030')
driver = webdriver.Chrome('./chromedriver.exe', options=option)
driver.implicitly_wait(5)


driver.get('https://comic.naver.com/comment/comment?titleId=796152&no=33')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
reviews = soup.select('span.u_cbox_contents')


# 전체 댓글을 연다.
# driver.find_element_by_xpath('//*[@id="cbox_module_wai_u_cbox_sort_option_tab2"]/span[2]').click()
driver.find_element_by_css_selector('#cbox_module_wai_u_cbox_sort_option_tab2 > .u_cbox_sort_label').click()
time.sleep(1)


# 1페이지 댓글을 읽는다.
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
reviews = soup.select('span.u_cbox_contents')
for review in reviews:
    print(review.text)
print('댓글 1페이지', '=' * 80, '\n')

count = 2
# 댓글 페이지 그룹 전체 개수가 몇 개 인지 모르기 때문에 무한 루프를 돌린다.
while True:
    page = soup.select('div.u_cbox_page_wrap > a.u_cbox_page')
    print('댓글 페이지 개수: {}\n'.format(len(page)))
    # 현재 댓글 그룹의 페이지 개수만큼 반복하며 댓글을 읽어들인다.
    for i in range(len(page)):
        # 다음 댓글 페이지를 연다.
        driver.find_element_by_css_selector(
            '#cbox_module > div > div.u_cbox_paginate > div > a:nth-child(' + str(i + 4) + ')'
        ).click()
        time.sleep(1)
        # 다음 댓글 페이지의 댓글을 읽는다.
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        reviews = soup.select('span.u_cbox_contents')
        for review in reviews:
            print(review.text)
        print('댓글 {}페이지'.format(count), '=' * 80, '\n')
        count += 1

    # '다음'을 클릭해서 다음 댓글 페이지 그룹을 연다.
    try:
        driver.find_element_by_css_selector(
            '#cbox_module > div > div.u_cbox_paginate > div > a:nth-child(13)'
        ).click()
        time.sleep(1)
    except:
        # '다음' 링크가 없으면 무한 루프를 탈출시킨다.
        break

    # 다음 댓글 페이지 그룹의 첫 번째 페이지 리뷰를 읽는다.
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    reviews = soup.select('span.u_cbox_contents')
    for review in reviews:
        print(review.text)
    print('댓글 {}페이지'.format(count), '=' * 80, '\n')
    count += 1
# Out:
# 마루가 사는 쪽이 ㅂㄱ천인지 똑같네요! 작가님께 마루는 순수한 사랑 그 자체인가봅니다. 저는 사실 동물을 무서워해서 가끔산책하다보면 불편할때가 종종 있었는데 앞으로는 우리동네에 마루가 있다고 생각하며 예쁘게 볼수있을것같습니다😊😊
# 아 너무 귀엽당....
# 임주스씨 주스 얼어서 슬러쉬 되겠어요
# 서율이 정수리 너무귀여워ㅋㅋㅋㅋ 앞으로넘어지고 우는거 참는것도 귀여워 빨아먹어 호로록
# 엉엉 검은고양이 내가 키울래 흑흑
# 탄아 너무 귀엽다..ㅠㅠ
# 치즈고양이 tnr 때문에 귀 한쪽 짤린거 디테일봐..
# 저러고 선물 막 소박하게 개껌 막 이러는거 아님? ㅎㅎㅎㅎㅎㅎㅎ
# 사랑해 마루툰 ㅠㅠ
# 나너무행복해...
# 아 진짜 힐링툰이다..💕
# 치즈고양이 양말냄새 맡고ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 여기 별점 10점말고 100000점은 못주나요..ㅠ
# 아무도 궁금해하지 않겠지만..치즈냥이가 양말 냄새를 맡고 ㅇ0ㅇ하는 표정을 짓는 부분이 있는데 실제로 고양이들이 냄새를 맡다가 저렇게 충격을 받은듯 입을 벌리고 멍한 표정을 지을때가 있습니다. 플레멘 반응이라고 하는데요, 악취에 경악하는 것이 아니고 보습 코 기관에 공기를 보내 냄새 물질을 검사할때 짓는 표정입니다. 고양이 외에도 고양잇과 동물인 사자, 호랑이 혹은 말이나 사슴도 이런 반응을 보이곤 한답니다ㅎㅎ 냥이들 충격받은듯한 얼굴이 사람이 보기엔 너모 귀엽죠ㅎㅎ
# 어..내 맘이 구름이 되고 있어...
# 댓글 1페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 어느 웹툰이든 보기만 했지 댓글을 남기는 건 처음이에요. 2년 전 무지개 다리를 건너 천국에 있는 반려견 이라 적는 것도 미안한 내 가족, 내 동생이 마루처럼 말할 수 있었다면 그 아이가 느끼는 세세한 감정도 모두 공감해 줄 수 있었을 텐데 하는 막연한 아쉬움이 들지만 동시에 마루를 보고 있으면 그냥 행복해져요. 조건 없는 내리 사랑의 표본인 강아지들의 순수함은 다 똑같아서 그런가 봐요 :) 이 만화를 그려주시는 작가님을 늘 응원합니다 :-)* 새해 복 많이 받으세요!
# 마루 강쥐 사실 끝이 뭔가 꿈이다 이러고 안 끝났으면 좋겠다ㅠ
# 생일 축하해 훅 들어오는구나 마루 멋졍>ㅅ<
# 살랑살랑 하는거~보들보들 한거~
# 흔들흔들 하는거~~
# o(>ㅈ<)o
# 별점 10점이 안 아깝고 줄 수 있다면 더 주고 싶음
# 마루언니의 머릿속 대사(아마도) : 마루가 철들었어 어느새 이렇게까지 쑥 커버린 거지 너무너무너무 기특하다 우리 마루가 언니를 도와주다니 언제나 사고만 치고 이거해줘 저거해줘만 할 줄 알았는데 빨라도 너무 빠른 거 아냐
# 탄이 고양이들이랑 담장 걸어가는 컷에 꼬리 잘려있네 ㅜㅜ 탄이 길고양이 였나부다 .......ㅜㅜ 행복해라 탄이두 길고양이두 모두..
# 자세히 보니까 치즈고양이 한쪽 귀가.... 잘려있네.....슬퍼졌음
# 이번화 거의 짱구급인데......!?????
# ㅋㅋㅋㅋ 마루 귀여워~ 크리스마스때문에 열심히 도와준거 였음!!
# ㅜㅜ최고의힐링웹툰이다
# 먀옥먀먀먀마옹
# 미치겠다 너무너무 귀여워
# 작가님 보들보들한거 찾을때 불광천 배경이죠!!?
# 하씨 이번화 역대급으로 학교에서 콧구멍 벌렁거리면서 봄.. 벌렁살랑살랑.. 탄이 귀엽다..
# 댓글 2페이지 ================================================================================
#
# 제 평생 소원인데 혹시 카톡 임티를 .... 출시 할 생각은 .. 없으신가오ㅠㅠ 시리즈 1000가지가 나와도 다 살게요 ...
# 으이익 귀여워.. 마루 너 혹시 옷에 도깨비풀 붙이고 침대올라간거 아니지... 귀여운것...
# 마루 진짜 너무 대견하다 크흦ㅂ.....🥺
# 아니 머리끈 마루 얼굴에 왜이렇게 찰지게 붙냐구욬ㅋㅋㅋㅋㅋㅋ
# 아 애들 왤케 귀여워
# 우리 품에 안겨있는 마루 너무 귀여워요........
# 냥이 또 나왔음 좋겠다
# 애옹이 기르는 집사로서이번편 너무 힐링이야!!!
# 선물은 또 어떻게 몰래 줘야 할까 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 마루가 점점 언어능력이 늘어가네요!
# 와 모냐 오늘 완전 몽글몽글해ㅠㅠㅠㅠㅠ🫶🏻🫶🏻🫶🏻
# 뜬금없지만 작가님은 개도 고양이 다 키우시니까 이렇게 탄탄한 이야기가 술술 나오시는거겠지? 주인공 우리처럼 단단한개랑 리틀죠 보고 상상한 내용이 이 작품이 되어서 나온거라고 생각하니 좀 몽글몽글,,
# 치즈고양이 길고양이인데 중성화해서 귀 한쪽 살짝 잘린 거 디테일 봐..
# 투니버스 챔프 보는 거 같고 너무 좋다😊
# 울음 꾹참는 서율이 따봉날리는 마루 귀여워
# 댓글 3페이지 ================================================================================
#
# 서율이 안울어할때 마루 법규하는줄..
# 이 웹툰만 보면 행복해짐 화욜에 보장된 행복
# 웹툰 다 보니까 맨 아래 애플워치 광고ㅋㅋㅋㅋ
# 힐링의 끝판왕이다ㅠㅠㅠㅠㅠㅠ
# 그 치즈 고양이 귀 끝 짤려있음 고양이들은 귀끝이 짤려있으면 중성화 했다는 뜻임 ㄷㄷ
# 몀며며왱애앵왕애앵
# 넘무 커여워
# 고양이들 줄지어 가는 장면보는데 왜 눈물이 나지ㅜ
# 노란고양이 길고양이라 많이 치이고 살았는지 오른쪽 귀 살짝 잘린거 디테일하다 ..
# 너무 사랑스러운 작품...
# 임주스씨 반팔에다 슬리퍼까지ㅋㅋ
# 따수해..
# 마루가 '비 밀~' 할때 심장이 터지는줄..마루 사랑해..
# 진짜 웃기고 따뜻하고 다 하는 만화..ㅠㅠ
# 넘나 잼나는 양말냄새 맡구치즈냥이 표정 저래 되는거
# 왜 암두 알안해여 ㅋㅋㅋㅋㅋㅋㅋㅋ
# 댓글 4페이지 ================================================================================
#
# ㄹㅇ 중고딩용 동화
# 저 애기도 마루처럼 고양이가 사람이 된건가
# 아니 작가님 왜 만점이 10점밖에 안돼죠?
# 작가님 마루 임티 만들어주세여ㅜㅜ 너무 귀엽다 증말..
# healing ohjeowyo
# 생각보다 애들 선물.. 단순하고 저렴한것도 좋아해요ㅋㅋ 매번 비싼것만 원하진 않더라구요ㅋㅋ
# 사랑스러워요
# 동화책 읽는 것 같다ㅜㅠㅠ 읽는내내 마음이 몽글몽글 하네요ㅎㅎ:)
# 재밌어요
# 별점 9.99 처음본다
# 마루야 싸랑해......
# to.산타산타할아버지 저는 소박하게 구삐랑 금은방에가서 골드바랑 람보르기니 타다가 엇? 사고가 났네? 바로 롤스로이스 사버리고싶고요 63빌딩이랑 롯데타워 사고 저희 형이 일론 머스크고 한 98조만 주시면 감사하겠습니다
# 헐 저게 왜 좋지?
# 앜ㅋㅋㅋ너무 귀여ㅇ웤ㅋㅋㅋㅋ 진짜 귀엽다는 말 밖에 할 수가 없다.....
# 냄새때매 꼬리펑된거 ㅈㄴ웃기다 ㅋㅋㅋㅋㅋ진짜 개귀여움 ㅠ
# 댓글 5페이지 ================================================================================
#
# 탄이 이주연닮음ㅜ
# 어딜가나 치즈고양이가 애교만점인듯!
# 이 웹툰을 처음 보는뎅 작가님 덕에 인생웹툰 찾았습니당!감사합니다!
# 고양이랑 마루랑 뽀뽀 백만번 하고싶다 제발
# 탄이 츤데레
# ㅠㅠㅠㅠㅠㅠㅠ귀가ㅠㅠㅠㅠㅠㅠㅠㅠ
# 감사해요.. 이런 만화 연재해주셔서.. 삶의 유일한 힐링
# 자꾸 보게 되네유
# 아 만화가 힐링 그 자체야 ...
# 치즈냥이 중성화 했규나 ㅠㅠ 디테일 장인..
# ㅋㅎㅎㅎㅎ졸귀다..
# 치즈냥이 중성화했구나 깨알 ㅋㅋ
# 단행본 나오나요....
# 아 진짜 너무 재밌다... 힐링된다....
#  마루야ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ
# 댓글 6페이지 ================================================================================
#
# 인간은 걸을 때 오른발이 나가면 왼 손이 앞으로 나가는데... 탄이랑 냥이들 담벼락걸을 때보면 탄이랑 괭이들 다 같은 발로 걸어가고있음 ㅠㅠ 디테일 무엇.. 탄이도 괭이인거야 ㅠ
# 원래 웹툰보고 댓글 잘 안남기는데 너무 재밌게 보고 있어요 너무 웃기고 재밌어요 그리고 캐릭터도 너무 귀엽구요
# 가능하시다면 마루 카톡스티커 출시해주세요 작가니뮤ㅠ 존버하겠습니다
# 고양이 이야기 보고 눈물 줄줄흐름... 왜우는지는모르겟는데 나도모르게 눈물이났음
# 너무 행복해지는 웹툰이에요
# 오늘 귀여운 포인크가 대체 몇개야....🥹
# 흠.....맥북....?
# 작가님 제발 이모티콘 내주세요 제발요 제발요. 제발 부탁합니다 이렇게 제 평생 이런 간절함 처음입니다. 부탁합니다 고려해주시요 돈많이 버시고 건강하시요
# 고양이는빌런이지
# 귀여워ㅠㅜ
# 마루 우리가 고맙다고 하니까 어깨 으쓱해지면서 웃는거 기여워...
# 마루야 기특해요
# 근데 마루랑 같이 다니던 치즈 고양이 중성화 수술했네?
# ??? : 강남의 건물 3채 사줘
# 탄이 왜 꼬리 끝이 둥글지않고 딱 잘리는거같지?🥺
# 댓글 7페이지 ================================================================================
#
# 마루 꾸깆 귀여워
# 여기는 작품 만큼이나 몽글몽글한 댓글들이 많아서 좋다..
# 애기들 너무 귀여워여
# 고양이 중성화해서 귀가 한쪽 잘린건가? ㅠㅠ 귀여워 ㅠㅠ
# 애들 다시 동물상태로 변하면 허해서 어케ㅠㅠㅠㅠㅠㅠㅜㅜㅜ
# 임주스씨 백수인감? 맨날 집에 잇네
# 치즈냥이 중성화 수술 했구낭.. 귀 짤려있넹..
# 모죠는 천재야...ㅜㅜ
# 아이고 리본가져간 고양이 중성화수술 했나보네
# ㅋㅋㅋㅋ멱! 이런사실적인 울음소리ㅋㅋㅋㅋㅋㅋ집사라 다 귀에서 들리는거같네요
# 아 귀여워미치겟다...ㅠㅠ
# 작가님 그립톡은 언제 입고 될까요 ㅠ마루가 너무 기여워서 꼭 사고싶어요 ㅠㅠ
# 고양이 한쪽 귀끝 잘려있는거 너무 디테일하고 귀여워요🥲😍
# 하 진심 이 웹툰 너무 힐링물이햐.. 계속 연재해주세요 젭앟 ㅠ
# 마루 그립톡 또 내주세요 ㅠㅠㅠ 살려고 했는데 품절.....8ㅁ8
# 댓글 8페이지 ================================================================================
#
# 고양이 굳어있는거 너무 귀엽닼ㅋ
# 아 ㅋㅋㅋㅋㅋㅋ서율이 안울고 일어나니까 마루가 따봉 하는거봐ㅠㅋㅋㅋㅋ이 귀여운 생명체들아ㅠㅠㅠ
# 임서율을 사랑하지 않을 수 없다
# 아진짜고양이든마루든왜케귀엽냐
# 이런게 왜 9.9? 10.0이 아니라?
# 살랑살랑 하는 거보들보들 한 거
# 흔들흔들 하는 거...
#
# 열심히 찾아다니는 애기들 모습 따수워...ㅠㅠ 요츠바랑 보던 때의 그 느낌 모죠님 덕분에 다시 느끼고 있다요 흑흑
#
# 와중에 마루 발 안 닦고 침대 올라갔으니 선물 압수
# 약점을 놀리거나 비웃는게 아닌 무의식적으로 고양이를 머리에 태우고 아무렇지 않게 함께 나아가는 장면이 인상깊네요.
# 분명개그툰인데 왜 눈물이 맺히쥬ㅜㅜ 기특해마루 크지망ㅜㅜ
# 댓글 1000!
# 아.. 나중에 특별편으로 탄이는 냥이! 같은거 올려주셨으면...
# 기야워ㅠㅠㅠ
# 진짜 존나 힐링이다
# 왜 별점 만점이 10점인 거야...난 백점 줄래요...
# 너무 귀엽고 힐링돼요☺️☺️☺️그림체 마저 귀엽규
# 귀엽고 하찮은것 원하는거 아닐까 ㅋㅋㅋㅋ
# 댓글 9페이지 ================================================================================
#
# 사랑스러워ㅠㅠㅠㅠㅠㅠ
# 그래서 멱 먀가 뭔뜻이야 마루야
# 그걸 벼락치기 하고있다니 ㅋㅋㅋㅋ
# 징차 볼때마다 드는 생각이지만..너무 귀여웡...♡♡♡
# 역대급 힐링화...
# 도대체 무슨 계절인지 알 수 없었던 화... 대사로 알았다 곧 크리스마스였어
# 으아아아ㅏ아아ㅏ앙아악 너무 귀여워 마루 사랑스러워 서율이도 너무너무 귀여워 너무 철들었어 언제 이렇게 컸니???? 너무너무 귀여ㅜ어 사랑해 소중해 사랑스러워 귀여워 최고야 멋져
# 치즈 냥이 왼쪽 귀가...
# 크리스마스에는 재미있고 튼튼하고 물기 좋은 냄새나는 것으로 주면 되겠네요!
# 그림체 병맛이면서 웹툰적이니 넘 맘에듬 ㅎ
# 치즈냥이 중성화 했네 ? 귀가 짤려있음
# 고양이 중성화한 작은 포인트까지 있네요너무 힐링되는 웹툰이에요!
# 작가님이 역시나
# 고양이는 정말 진리아님?
# 님들 마루 계좌 좀 내가 산물 줄게
# 댓글 10페이지 ================================================================================
#
# 마루 큰 모습 궁금하당ㅋㅋ
# 미리보기가 얼마나 많길래...여긴 설날인데 과거인들은 크리스마스도 안 지났네??
# 마루가 서율이한테 뻐큐하는데요?
# 고양이남자애 니가 남주해라
# 마루 따봉을 욕으로 봐버렸다..
# 근데 마루 사람 귀가 없다 ㅋㅋㅋ 고양이 애기는 사람 귀 있는데
# 아 이번화 진짜진짜 힐링 ,,,,🌸💛
# 탄아 생일축하해 🎂 ͜ (ᵔ ̮ ᵔ)›
# 먀~
# 노잼억지감동...
# 작가님 마루는 강쥐 이모티콘... 해주시면 안될까요..? 진짜 이모티콘으로 마루의 그 다양한 표정.. 톡할때마다 쓰고 싶어요ㅠㅠㅍ
# 치즈냥이 또 나와줬으면 좋겠다...
# 엌ㅋㅋㅋ
# 탄이 생일 축하한다는 말 들으니까 얼굴 약간 빨개진 것 같은데 너무넘무 귀엽당
# 애니제작원츄ㅠㅠ 카톡티콘원츄ㅠㅠ 이거우리딸도 보여주고싶다ㅡ한글조기교육시키는중
# 댓글 11페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# ㅋㅋㅋㅋㅋ빨래 개어둔 거 다 흘리고 다니는거 너무 기엽다.. 선행 벼락치기ㅋㅋㅋ
# 강아지풀 하찮아..♡
# 어라 저 마루 도와준 고양이 의 귀가.......
# 심하게 귀엽고 힐링되는 웹툰이에요,,,🥰
# 난 가끔 이 웹툰 작가가 모죠님인 걸 까먹는다...
# 몽글몽글해서 너무 젛아요
# 점점 갈수록 웹툰이 짧아지고있쒀...!
# 고양이 귀 좀 짤린거 중성화수술했다는 표시인가
# 고양이 귀한쪽 잘려나갔넹ㅜ 귀엽긴 겁나 마루 만큼 귀엽다 .
# 고양이 중성화 했나보다 귀가 한쪽 잘려잇네
# 아..힐링 돼…
# 고양이 그와중에 중성화....
# 제발요. 마루는 강쥐 어린이들 필독서해야해요. 애니메이션화해야해요. 아이들이 보면서 자라야해요🥲🥲🥲 어른을 위한 동화 뭐 이런 상 받아야한다구요. 있는상없는상 다 모죠님드려야함. 사랑스러워.....
# 하 너무 너무 좋다 볼수록 마음이 따뜻해져
# 진짜 힐링물이다ㅠㅠ 귀잘려잇는것도 현실반영 100프로... 우리 불쌍한 길냥이들...다들 행벅햇음 좋겟다ㅠㅠㅠㅠㅠ좋은 사람 만나서 다들 집사 찾았음 좋겠어 냥이들,,
# 댓글 12페이지 ================================================================================
#
# 치즈고양이 귀 잘려있당 중성화 했구나
# 생각해 보니까 저 풀 이름이 강아지풀
# 마루 is 최강 갱얼쥐
# 가족이 서로 꼬물꼬물 몸 맞대고 혼곤히 잠드는거 세상의 모든 평화다
# ටㅏ 이번편 진짜 제대로 힐링된다
# 따땃해져ㅕ
# 마루 개귀엽네 ㅠㅠㅠㅠㅠㅋㅋㅋ
# 웅먕맥?
# 아사랑스러워..아눈물나
# 그 와중에 마루 빨래 갠 거 다 흘리고 있어ㅠㅠㅠ
# 열심히지가 맞는 말인가요...?
# 이 웹툰 진짜 사랑해,,
# 탄이 강아지풀 들고 뛰어댕기는거 너무 귀엽다
# 치즈고양이 길 고양이라서 귀 한쪽이 약간 없네...ㅠㅠㅠㅠ슬프다ㅜㅜㅜ작가님 디테일하게 그리셨어...
# . ....*됬.
# 댓글 13페이지 ================================================================================
#
# 살랑살랑 하는 거, 보들보들 한 거, 흔들흔들 하는 거.. 동화책 같고 너무 좋아하는 부분이에요
# 우리집 고양이는 응으응애앵앵 하고 우는데ㅡㅡ
# 임주스 반팔ㅋㅋㅋㅌ
# 안울어 할때 마루가 가운데 손가락 드는줄 알았네 ㅋㅎㅋㅎㅋㅎ
# 집이없어보고 우울하다가 마루보고 힐링
# 카*오톡 마루 이모티콘 맹글면 바로 구매인데
# 얘들아 산타는 없어. 물주가 있을 뿐이지
# 진짜... 귀여워..... 진쫘.. 쭈아압
# 아앀ㅋㅋㅋㅋㅋ 고양이 울음소리 역대급.. 현실고증 쩐다 작가님 고양이 키우져
# 서율이는 햄스터 아냐? 어린이집 쌤은 뱀인가...
# 마루쉐~~
# ㄹㅇ 길고양이 귀 한쪽 잘려있는거 표현 잘하셨네...
# ㅋㅋㅋㅋㅋㅋㅋ ㅋ양말 냄새 맡은 야옹이 표정 뭔지 알 것 같아서 개웃김ㅋㅋㅋㅋ
# 귀여워.
# 귀여어
# 댓글 14페이지 ================================================================================
#
# 서율이도 귀엽다
# 다들 너무귀엽다
# 그래놓고 애기들이 쓴 편지보면 되게 소박한거 바람.... 너무 귀여워..................
# 마루는 왜 맨날 같은 옷일까...?ㅋㅎ
# 큰 개껌
# 우리집 애들도 저렇게 대화 좀 하고 잘 지내면 좋겠다...  오늘도 마루 귀엽~
# 치즈..... 이제봤는데 중성화 되있네?
# 이걸... 설도 다 지나서 보다니
# 이빨요정만해도 겁나 빡센는데 후속타인 크리스마스.......언니 골때리겠는데?
# 아휴 너무 귀여워서 눈물나요 ㅠㅠ
# 탄이 꼬리.. 귀여워...
# 너무 재밌고 힐링돼요 제가 본 웹툰 중에 가장 좋아요 오래오래 연재해주세요 감사합니다
# 치즈냥아 설마 중성화했니...?
# 진짜 마루보다 귀여운 캐릭터는 없다 ㅠ
# 중간에 꼬순내 나는 장면이...킁ㅠ
# 댓글 15페이지 ================================================================================
# 마루야 대단하다 언니 머리끈 찾아주고 빨래도 같이 개껴주고 대견해 (목적은 선물때문이었지만;;)그래도 서율이도 넘어졌는데 울지않고 착해^^ 귀여운것드을~~
# 노란고양이 중성화해서 귀 짤린거 현실고증 미쳤다ㅠㅠ
# 그래도 진짜 너무 착하고 귀엽다ㅜㅜㅜ ❤️
# 고먐미도 귀엽구 마루도 귀엽고 ....임종하겠다.
# 치즈고양이... 오른쪽 귀가 잘린걸 보니 중성화를 했나보군요......네...힘내라...
# 이 웹툰은 마음이 치유가되는 신기한 웹툰같아ㅎㅎ 뭔가 생각이나 마음이 치유가 됌 (>^•^<)
# 저 갈색 고양이 마지막에 먀 그거 고맙다는 건가? 기엽다ㅠ
# 이 만화는 평생 연재해주셔야합니다제발요 탄이마루서율다행볻해라❤️🤤
# 진짜로 너무 귀엽고 무해하고 사랑스럽고 따뜻해서 눈물이 멈추질않아요ㅜㅜㅜㅜㅜ
# 요즘 이게 젤 재밌다
# 귀여우어ㅓ어어엉어ㅓ어ㅓ어ㅓ어어어ㅓㅇ
# 어케이렇게 귀여운 웹툰이
# 막 탐험해서 찾아놓구 언니한테 티도 안 내는 우리 마루... 너무 기특하고 꼬옥 안아주고 싶어
# 마루 너무 사랑스러워~♡
# 진짜 완전 힐링웹툰이다.. 포근해지는거 같애
# 댓글 16페이지 ================================================================================
#
# 치즈냥이도 하나 주지
# 강아지풀 안에 벌레 있을텐데....
# ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ고앵이가 배애앵 하는 표정 진짜 구린내맡은 고양이 표정이라 댕터짐ㅜㅠㅠㅠㅜㅠㅠㅜ
# 너무 따뜻해서 눈물나는 웹툰
# 산타할아버지..저는 현금으로 주세요..
# 오늘도 힐링....코가 찡..... 동물 친구들아 사랑해
# 이번화 역대급 힐링이다,,
# 모죠...당신 머릿속에 귀여운게 많군요...
# 마루너무조아 마루마루마루마루마루마루사랑해화요일만기다린당마루사랑해마루넘기여워
# 양말 냄새 맡은 치즈냥이 표정ㅋㅋㅋㅋㅋㅋㅋ인스타에서 많이 본 그 표정이다
# 마루야 사랑해..
# 어떻게 된 만화가 처음부터 끝까지 귀엽고 사랑스럽고 웃기고 그러냐 ㅋㅋㅋㅋㅋㅋ
# 하 마루야ㅜㅜㅜ❤❤❤ 사랑둥이
# 아 너무너무 귀엽고 따뜻하고.. 최고야ㅠㅠ
# 귀여웡❤️❤️
# 댓글 17페이지 ================================================================================
#
# 길고양이 중성화해서 귀 한쪽 짤린 거까지 디테일 너무 좋다
# 아 너무 귀여워서 심장이 박살나
# 아~~~~~~~~~~~~ 힐링 그 잡채~~~~~~~
# 넘넘넘 넘넘넘 편안해 집니다~!!
# 하.. 탄이 혹시 유기묘인걸까..탄이는 왜 마루처럼 가족이 없을까 하고 생각해봤는데 길냥이들 위에 군림해서 사는 게 아무래도 길냥이로 태어났거나 이건 아니길 바라지만 유기묘인 듯..
# 모죠양은 무슨 일상툰도 잘그리고 요런 몽글몽글 기분이 따닷해지는 것도 잘그리는 고얌~~~
# 앗...저 다리 똑닮은딸에 나오는 다리 아닌감
# 단행본 나오면 노후준비 할 겸 꼭 산다마루 얼굴만 봐도 내 잇몸이 인사하로 나오네
# 탄이 정말 고양이의 특징을 모조리 빼다박음 강아지풀에 금세 마음 기울어놓고아닌척 이제 질렷어 라며 던져주는 고양이... 그러면서 속으로 엄청 좋아할 것 같아서 넘 귀여움 ㅠㅠㅠㅠ 마루 잠귀도 밝을 것 같은데 언니가 괜히 어쭙잖게 산타 흉내 내다가 걸리는 건 아닐지 심히 걱정되네요... 산타... 성공하길...
# 오늘 힌컷한컷마다 사랑스럽고 귀엽고 따뜻하고 재미있고...
# 살랑살랑하고 보들보들하고 흔들흔들하구만...
# 진짜 사람손 많이 탄 고앵이가 진짜 신뢰하는 사람글에게만 들려주는 소리까지,, 어쩜이리도 잘 아시는거지...?
# 치즈냥이 귀 짤린거 보니까 중성화 했구나
# 그.. 저.. 얘들아 사랑한다..❤️
# 이제 우리,주스는 그냥 가좍아니냐
# 하...탄이
# .....너무......... .. . .......귀엽고..........마루....................생일축하해주는거 정말..,........... ......    . .... ...다정하고.............귀엽고예쁘고......ㅠㅠㅠㅜㅠㅠㅜㅠㅠㅠㅠ
# 댓글 18페이지 ================================================================================
#
# 아니 치즈 냥이 중성화하면 귀 컷팅하는거 (맞나요?) 디테일 뭐야? 이제봤으.. 작가님 진짜 섬세하세요. ....
# 모죠 당신 천재지.. 모죠의 일지같은 빵빵 터지는 웹툰 뿐 아니라 이런 몽글한 스토리까지 완벽하게 그리다니.... 사랑해요....
# 고양이는 충격적인 냄새를 맡으면 입이 아- 벌어지는데 너무 똑같애ㅋㅋㅋㅋㅋㅋㅋㅋㅜ
# ak...마루 따봉 임티를 가지고 싶다
# 사랑스러워
# 고양이들 키우고 있어서 탄이편도 따로 격하게 보고싶다 ㅠㅠ'탄이는 냥이' 이렇게 흑흑
# 아진짜 최고... 마음 너무 몽글몽글... 너무 귀엽고 착해... 감사합니다 작가님
# 치즈냥이 중성화 되어있는거 ..
# 동생...
# 와 포인트포인트마다 거를게 없다... 고양이도 탄이도 마루도 서율이도 다 너무 귀여워ㅜㅜㅜ
# 너무 사랑스럽다........
# 하...........................탄이 아기야.......,,,,.,,,,,너무 귀엽다......,,,,,......
# 하 마루 이 아기갱얼지 빨래 옮기는거 도와주고 넘 기특해 물론 다 흘린것 같지만 귀여워
# 마루 서율이핞테 욕한줄
# 헉 탄이 꼬리
# 댓글 19페이지 ================================================================================
#
# 너무 귀여워ㅜㅜㅜㅠㅠ
# 착한일 벼락치기 공감ㅋㅋㅋㅌㅋㅋ 근데 엄마는 그때만이라도 편해서 다행이었다고 함
# 냥이 tnr해서 귀 끝에 잘려있는 디테일!
# 마루는 산타할아버지께 뭘 받고 싶어? 라고 물와봐
# 마루는 강쥐 불광천에서 찍었나 겁나 익숙하다
# 서율,,, 그 서율도 저렇게 순한 범생st였는데
# 너무 귀엽다
# 치즈냥 귀 잘려있는 거 현실적이네
# 아 진짜 뽀짝해...ㅠㅠㅠ
# 너무귀여워서 죽고싶다
# 진짜 다 너무귀엽다...ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 너무 귀엽다 귀여워 얘들아...
# 탄이 신하 귀가 왜 짤려있어
# 살랑살랑 보들보들 흔들흔들 강아지풀~ 고양이군단 이끌고 탄이 뭐하고 노는지도 궁금하다ㅋㅋ
# 이번화 진짜 몽글몽글.......하.........사랑해요
# 치즈냥 양말냄새 맡고 입 헤~ 하는거 완전 고양이ㅋㅋㅋㅋㅋㅋㅋㅋ 헤 하고 충격먹을 정도면 항문낭냄새 그 이상인데ㅋㅋ
# 댓글 20페이지 ================================================================================
#
# 왜캐 다 깜찍혀ㅜㅜ
# 마루야 ...사랑해.....!!!! ㅜㅠㅠㅠㅠㅠ꒰⁎′̥̥̥ ⌑ ‵̥̥̥ ꒱
# 작가님 제발 마루 이모티콘 만들어주세요(새해 소망)
# 작가님 마루 이모티콘 출시해주세용 ㅠㅠㅠㅠ 이렇게 귀엽고 이모티콘같이 생긴 마루를 퓨ㅠ
# 으어 너무 늦게 알아버린 웹툰 보면서 힐링....되는 그나저나 겨울인데 임주스씨는 반팔에 슬리퍼네....
# 순딩이덜,,,이러고 있었는데 너희는 다 계획이 있구나?ㅋㅋㅋㅋㅋㅋ귀엽다❤️🫶
# 아 비밀 했을때 울컥해서 울어버렸어
# 혹시 치즈냥이 중성화........? 귀 한쪽이 잘려있는데
# 서율이 안운다 할때 마루 따봉하고 있네ㅋㅋㅋㅋㅋㅋㅋㅋ
# 영원히 연재했으면 좋겠어요
# 살랑살랑...보들보들...흔들흔들한거? 그거 내 마음이다 마루야 ㅠㅠㅠㅠㅠㅠㅠ
# 치즈냥이 tnr해서 귀컷팅한 디테일까지 대박,,,작가님,,
# 고양이 귀 길이가 다른이유가 유기묘들은 중성화시켰으면 저렇게 표시한다구 합니다 귀에 신경이 없어서 잘라도 안아프대용
# 이 귀여운 것들..
# 할로윈도 그렇고 크리스마스도 미리보기 나오는 시점에 맞춰서 연재하시는구나... 아무리 꾸준히 쿠키 쓰는 분들이 소중하고 중요하다지만 이건 좀ㅋㅋ 본 연재일은 오늘 아닌가요? 주제 넘은거 잘 알지만 괜히 서운하네요
# 댓글 21페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 여기는 설날연휴가 하루남았어......
# 이 와기들..너모 말랑뽀짝해ㅠㅠㅠㅠㅠㅠ 최고의 힐링툰ㅠㅠ 글고 냥이랑 강쥐랑 좋아하는거 다른것도 너모 귀여우뮤ㅠㅠㅠㅠㅠㅠㅋ큐ㅠㅠㅠ
# ㄴ ㅏ도마루랑느긋하고한가로이부비적거리면서누우ㅓ잇고시퍼
# 빨래 다 흘렸어 ㅋㅋㅋㅋㅋ
# 치즈냥 중성화 했구나 한쪽귀끝 잘린거 ㅠㅠㅍ기엽
# 준호 이름 부르기 캠페인 (1/24800)
# 근데 마루 ㅋㅋㅋㅋㅋ 평소에 언니랑 있을땐 말 되게 짧게 단어로 하고 얼버무리고 하더니 탄이랑은 아주 문장구사가 쭉쭉 ㅋㅋㅋ 어리광 부리던 거였구나 하긴 애들도 학교친구들이랑 부모님이랑 대화하는게 다르다더라...
# 고양이랑 마루랑 대화하는 부분 넘 귀엽고 보기 좋아요 🥹
# 흑..흑... 미칠듯이귀욥다..
# 아진짜 보는 내내 너무 행복해진다...
# 치즈냥이 TNR한 길냥이구나! 귀커팅 되있네
# 귀여워..... 마르...
# 마음이 따땃해진다...
# 귀여워
# 마루야 진짜 기특하다 ㅜㅜ
# 댓글 22페이지 ================================================================================
#
# 다들 너무 귀엽따
# 넘 재밌어유
# 탄이 꼬리 끝이.. 아니지?
# 탄이진짜너무ㅠㅠ귀야워ㅠㅠㅠㅠ생일 축하해받구 부끄러워서 질렸다하구 가버리는거ㅠㅠㅠ하아 까망아기괭이야..
# 간단하게 스위치 신형 나온거 사줘요
# 냄새나는 양말이요
# 빨래 다 망가졌엌ㅋㅋㅋㅠㅠ 마루야 ㅋㅋㅋㅋㅋ
# 이번화 왤케 힐링이야... 아니 사실 여태 계속 너무너무 귀엽고 힐링이긴 했지만 이번화는 진짜 더더더 힐링이고 귀여워
# 빨래 결국 다 흐트러졌어ㅠㅠㅋㅋㅋㅋ마루야ㅋㅋㅋ
# ??잠깐 나만 본거야??아님 실수야???탄이 꼬리 잘려있는것같은데...???
# 할아버지 괜찮아요 전 그냥 강남에 아파트 한채만 부탁드려요
# 귀여운 아가들 .. 어쩜좋아 입에 왕 넣고싶네 ㅜㅜ
# 마루 머리 위에 치즈냥이 얹고 가는거 넘 스윗졸귀여..
# 서율이는 장난감같은거 받고싶어하고 마루는 강아지육포(비쌈)받고싶어할듯ㅋㅋ
# 그러고보니 치즈냥이 중성화했나? 귀가 조금 잘려있네
# 댓글 23페이지 ================================================================================
#
# 아 너무 귀여워ㅠㅠ
# 예쁜 만화
# 또 이 따수분 어른들은 아이들을 위해 무엇을 해줄까
# 행복하다
# 탄이도 너무 귀여워요ㅠㅠㅠ 자주 출연시켜 주세용ㅜㅜ
# ㅠㅠㅠㅠㅠㅠ너므귀야웡...
# 귀여워
# 탄이랑 고양이들 너무 귀엽다 ㅜㅜ 생일 축하한다는 말 듣고 주는 것도 넘..🥹
# 아.. 오늘 완전 보노보노를 연상시키는 힐링이었다가 막판엔 아빠미소를 짓게 만드네요. 나 아빠도 아닌데;;
# 그게 목적이였군...
# 마루야... 너 살 너무 쪘다...
# 잘생겼어ㅜㅠ장발 최고
# 진짜 마루 너무 사랑스러워 이모네집에도 들러줘 볼뽀뽀움뫄 해줄게......
# 귀여워
# 여기 캐릭터 왜 다 귀여움...??? 모죠님은 유죄야 유죄.. 어떻게 이러케 기엽게 그려버리셔서 독자들 심쟝을 뽀개는거죠?!!??!?
# 댓글 24페이지 ================================================================================
#
# 행복해... 진짜루....
# 서율이 안 우니까 마루 따봉하는거 봐 ㅋㅋㅋㅋㅋㅋ
# 내가 이거 볼 때는 설날인데...
# 치즈냥이 중성화 수술 했나? 귀끝이 조금 잘렸네🤣
# 하...귀여워 오늘 하루 마무리는 마루로 하길 너무 잘한느낌... 힐링 그 자체
# 마루한테 아기냄새 날 거 같음,,ㅜㅜ 진짜 너무 말랑말랑하다
# 마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루기여워마루귀여워마루귀여워마루귀여워마루귀여워마루괴여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루기여워마루귀여워마루귀여워마루귀여워마루귀여워마류기여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루기여워마루귀여워마루귀여워마루귀여워마루귀여워마루괴여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루기여워마루귀여워마루귀여워마루귀여워마루귀여워마류기여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루기여워마루귀여워마루귀여워마루귀여워마루귀여워마루괴여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루기여워마루귀여워마루귀여워마루귀여워마루귀여워마류기여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워마루귀여워 휴ㅠㅠㅠ 힘들었따
# 으악 너무 귀여워서 육성으로 소리 질렀어용오옹!!!!
# 곧 크리스마스라더니 누구는 반팔을 입고있네ㅎ
# 고양이 귀 잘린거 현실고증 지린다..
# 결혼.
# 귀가 잘린건 중성화 흔적이에요ㅋㅋㅋㅋ 학대가 아니라
# 마루그립톡 광고는 있는데 재고가 없으면 어떡해요 ㅜㅁ ㅜ
# 아가치즈냥이 왜 귀가 잘렸어 ㅜㅜ
# 아 너무너무 힐링된다..ㅠㅠㅠㅠㅠㅠㅠ 세상 모든 강아지 고양이들 아프지말고 행복하기를 ㅠㅠㅠㅠㅠㅠㅠㅠㅠ
# 댓글 25페이지 ================================================================================
#
# [객관식문제] 대한민국의 어느 어린이들이 선물한번 받겠다고 착한일을 벼락치기로 연말에 하고있다. 이때 선물을 주는 산타가 취해야 하는 행동은?(5점)
#
# 1. 벼락치기라도 착한일이니까! 선물을 준다.
# 2. 니네는 귀여우니까 특별히...선물을 준다.
# 3. 니네는 매력 넘치니까 특별히...선물을 준다.
# 4. 니네는 뽀쟉하니까 특별히... 선물을 준다.
# 5. 니네는 발랄하니까 특별히... 선물을 준다.
# 치즈 고양이 옛날에 학대라도 당했나...귀 한쪽 모서리쪽이 잘려있나..
# 기여버
# 아후 서율이 올만에 보니 또 너무 귀엽네
# 하너무귀여워서 눈물이날꺼같애...
# 귀여워💕💕💕 작가님은 마음이 참 따뜻하신 분인 것 같아요. 한 해 동안 마루는 강쥐 보며 행복했어요. 작가님 고마워요. 새해 복 많이 받으세요❤️❤️
# 혹시 중성화한 고양이라고 표시하려고 한 쪽 귀를 다르게 표현하신 걸까요?ㅎㅎ마루 치즈 탄이 다 사랑스러워요❤️❤️
# 너무 힐링돼 ㅠㅠㅠ
# 아 그냥 다 완벽해 으아악 내 심장 1064191번 뺏긴다
# 애옹이 너무 귀엽다...
# 아니 임주스씨 곧 크리스마스인데 반팔입은거에요?!
# ???: 산타할아버지 저는 동생 갖고싶어요!
# 아 치즈냥이... 마루한테 고맙다고 한거겠지? 너무 귀엽다
# 우리는 벼락치기의 민족이죠. 개학이 이틀후인 저도 내일 벼락치기 합니다.
# 애니 만들어줘요 맴이 따뜻해진다 진짜
# 댓글 26페이지 ================================================================================
#
# 탄이 꼬리 끝이 살짝 잘려있는 것 같은데..ㅠㅠㅠ 무슨 일 있었나??
# 아 둘이 선물 찾는거 동화같고 너무 힐링된다.. 행복 ....
# 스트리트 출신이라 애들이 귀나 꼬리 조금씩 잘려있구나
# 진짜 사랑혀 아가들아........🫶🫶
# 진짜 힐링..... 귀여워죽겠다 냥이도 마루도 탄이도.... 강아지풀 들고 냥이들이랑 총총 걸어가는 탄이... 침대 꾸물꾸물 기어들어가서 얼굴 맞대고 자는 마루.... 다 너무 귀엽고 사랑스러워ㅠㅠㅠㅠ 흐엉.... 이거 진짜 애니로 만들면 둘리급 국민 만화 될 거 같음......
# 탄이 귀엽다
# ㅜㅠㅡㅠㅠㅜ너무귀여워너무귀여워
# 길냥이 문화충격.
# 마루:산타 할아버지께 강남 아파트 한채만 주세요
# 마루 임티 좀 만들어주세요!
# 너무너무 귀엽다... 살랑살랑 보들보들 흔들흔들 하면서 가는 거랑 아기고양이 머리에 얹는 거랑 동화 같고 넘 예뿌다
# 색감이 너무좋다
# 난 크리스마스에 선물로 산타 하부지께 남친을 빌었지..
# 베댓 다 12월 5일 거여서 순간 잘못 들어온 줄
# 강아지풀 생각했는데 진ㅊㅏ 강아지풀 가져왔네ㅋㅋ
# 댓글 27페이지 ================================================================================
#
# 진자 탄이? 개귀여워서 ㅁ죽을거같ㅁ음진자
# 마루야...서율아.....너희들 그럼 안돼....너무 귀엽자나...작가님....평생 완결 안 하시고 연재하실 거죠? 그럴 거죠...?우리 마루 강아지 돼고 사람들 다 상황 알고 그래도 좋으니까 계속 연재해 주실 거죠? 그런 거죠?
# 아 냥이랑 같이 뽈뽈뽈 다니는 거 너무 기엽다... 물 못건너서 마루 머리위에 타는 것도 넘기여우누ㅜㅠㅠㅠㅠㅜㅠㅠㅠㅠㅠㅠㅠㅠ
# 치즈냥이 귀 짤린 거 맴찢
# 이거 강형욱님아 리뷰해주심 좋겠다ㅋㅋ
# 치즈냥이 귀 한쪽 잘린거..
# 치즈냥이 중성화했나봐요
# 마루가 개에서 사람이 된 것처럼,탄이는 고양이에서 사람이된게 맞는 것 같은데...그럼 두 아이들 말고도 반려동물이 사람이 된 케이스가 더 있으려나?
# ㅇㄴ 탄이 질렸다면서 츤츤거리게 머리끈 주는거 개귀엽네
# 아 마루덕분에 넘 행보캐~~~~
# 아 오늘도 구엽다
# 아니ㅋㅋㅋ 고양이 양말 냄새 맡고 플레멘 반응 온 거 너무 웃긴데 베댓에 없다뇨!
# 헐 오늘 딱 생일인데….가족들도 내생일 까먹었는데…마루가 축하해준기분…기분이 몰랑몰랑…ㅠㅠㅠ
# 마루는 사랑입니다
# 에욱
# 댓글 28페이지 ================================================================================
# 살뢍살뢍해 뫌왕뫌왕해~
# 12월의 계엄사령관 산타클로스
# 치즈냥이 중성화했구나
# 근데 치즈 고양이 귀 살짝 잘린? 거 보면 중성화 했나본데
# 맘이 넘... 따땃해진다... 우리 마루 새해에는 뭘 받았을까...
# 오늘은 설인데..여긴 아직도 크리스마스 ㅠ
# 멱! 먀~
# 멍냥조합 귀여워 죽을거같애여,,
# 나중에 진짜 저둘이 결혼하는거 나만보고싶나...?
# 아악 힐링되는 장면들 보면서 왜이렇게 눈물이 나는거야 나도 저 세계관에서 살고 싶다...
# 서늘~
# 마루는 강쥐의 모든 화들을 사랑하지만 오늘 회차는 진짜 역대급 화인거 같아요.. 최애회차 된 듯ㅠㅠ 너무 몽글몽글하고 따듯하다...
# 마루♡서율vs마루♡탄이 진짜 상상만해도 넘 졸귀탱♡ (그리고 준호♡우리 커플(?))
# 마음이 따숩다
# 애들마음을 어떻게 이렇게 착 캐치할까... ㅎㅎㅎㅎ상냥한 우리
# 댓글 29페이지 ================================================================================
#
# 서율이 인사할 때 동그란 정수리가 너무 귀여움 ㅜㅜㅜㅜㅜ
# ㅋㅋㅋㅋㅋ귀엽다
# 근데 치즈냥 귀 잘린건 무슨사연일까..
# 시율이는 원래착한데...귀여워!
#       (마루도 귀여움!)
# 치즈냥이 TNR(중성화수술) 했나부당.. 작가님 귀 잘려있는 디테일👍
# 진짜 힐링 웹툰.. 내용도 등장인물도 그림도 다 넘 귀엽구 소중ㅠㅠ
# 마루 우리 똥강아지 귀여워 죽겄네 ~
# 재미있는 냄새가 나고 물어뜯기 좋고 튼튼한거 선물받고싶어하는데요...
# 왜 내 마음이 따뜻해지고... 내 미래가 아득해지고...
# 귀엽다 귀엽다😍😍
# 아!!! 귀여워!!!!!
# 진짜 댕냥이들 너무 귀엽고 힐링 ㅠㅠ 소중해
# 서율이 "안 울어!"  했을때 마루가 따봉하는거 보고 ㅃ큥인줄ㅋㅋㅋ
# 치즈냥이 귀 한쪽끝 잘려있는거보니 tnr했나봐 휴 근데 왜 짠한 마음이 들까ㅠㅠ
# 마루야.......마루야아아아아악
# 댓글 30페이지 ================================================================================
#
# 저는 집사주세요
# 아 ㅠㅠㅠ 고앵이들도 더 나오면 좋겠다 탄이 주인도 진짜 궁금ㅋㅋㅋ
# 힐링 지대로다…ㅠㅠ
# 으악 너무 힐링...
# 탄이 이 귀염뽀짝 아기 고양이 같으니... 할미는 당장 기쁜 공중제비를 돌다.
# 귀여워서임종하다
# 주스씨 토요웹툰 전생연분 이진수랑 닮은 것 같아요!
# 마루 사랑해 최고강아지마루 오쪼쪼
# 이번엔 선물 잘 전달 할수 있을까? ㅋㅋㅋㅋㅋㅋㅋㅋ
# 어린이에게는 해피 어른들에게는 공포
# 길고양이 중성화 한 거 치즈고양이 귀 표현 완전 섬세하다
# 마루야 오래 살자 ㅜㅠㅠㅠ
# 모죠 너무 재밌어서 이마를 쳤더니 10점을 눌러버렸어요...
# 근데 치즈고양이 왜 한쪽 귀 잘렸지...
# 너무너무너무너무너무 귀여워!!!!!!!!!!!ㅜㅜㅜㅜㅜㅜㅜㅜ
# 댓글 31페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 마루한테는 양말주면 되겠는데?ㅋㅋㅋㅋㅋㅋㅋ
# 고양이들 줄지어 걷는 것도 너무 기엽고 아가들도 너무 기엽다 ㅠㅠ
# 아 진짜 너무너무너무 힐링이다 ( ᵕ_ᵕ̩̩ )
# 힐링된다
# 너무 이쁜 만화,,!!!!
# 너무 힐링이다.. 하루종일 힘들게 일하고 밤에 마루는강쥐 보면 스트레스가 다 풀리는 느낌
# 멱멱 먀아~~
# 따봉마루ㅎㅎㅎ
# 너희 겨울이였냐뇨
# 귀여워ㅠ
# 귀여워ㅎㅎㅎ
# 고양이 귀 섬세한 표현이네요
# 임준호씨 이젠 연말이 좋아질걸ㅋ
# 마루야 사랑해 마루야 고마워~~~~~
# 엉엉어헝너무귀여워따뜻해
# 댓글 32페이지 ================================================================================
#
# 치즈 중성화 했구나..
# 근데진짜 이마루의해맑고골때리는 저표정은어케표현하시는거지 그림을 잘그리는거랑은 별개로 너무너무맛깔남
# 너무너무 귀여워
# 마루는 클래스 101에 격투기 클래스로 전직하는 강의를 갖고 싶다고 합니다 지금 바로 클래스 전직 강의를 들어 1세대 전직을 하세요!
# -서울대 판타지과 홍길동 (4차 전직)
# 우리 마루 새 칭구도 사귀고ㅠㅠㅠㅠ
# 마루 도와준 냥이 귀 끝 잘려있는거 봐 중성화했나봄ㅋㅋㅋㅋ
# 매주 마루는 강쥐만 기다리고 있어요,..뭔가 모르게 마음이 찡해지면서 뿌듯한 힐링물
# 모든 작들이 너무 사랑스럽고 힐링이 돼요
# 모죠님 너무 감사해요
# 연말인데 왜 반팔입어
# 아 귀여워 진짜ㅠㅠㅠㅠㅠ 매화마다 힐링돼요🥹
# 오늘도 힐링하고 가요~~
# 벌써 사랑이야기 10회까지 만들어버렸다..
# 마루 웃는거 귀여워 마루 이모티콘 시급ㅠㅠㅠㅠㅠ
# 개 귀여워ㅜㅜㅜ
# 탄이 애들 졸졸 몰고가는거 왤케 기엽냐ㅋㅋㅋㅋㅋㅋ
# 아니 마루야 엄지 척 한거야? 너무 귀여워어어어ㅓ어어어어ㅓ어어어
# 댓글 33페이지 ================================================================================
#
# 치즈 냥이 귀 조금 잘려 있는 거 TNR 인가요? ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 마루 볼 때마다 마음이 따수워요 🥹
# 냥카인
# 애니화 존버합니다 ㅜㅠㅠㅠㅠ 넘 귀여워
# 마루는 아이폰14프로를 가지고싶다고하네요(?)
# 플레멘
# 치즈냥이 중성화 해서 귀 끝 잘려 있는 디테일까지 표현하셨군요! 이번 화 킬포 많은거 귀엽고 웃기고ㅋㅋㅋㅋㅋ
# 진짜 너무귀여움... 살부비고자는거 우리애깅이랑 똑가테
# 아 고양이 저런꼬린내 맡으면 입벌리고 눈땡글 표정짓는거 똑같애욬ㅋㅋㅋㅋㅋ
# 츤츤대는 탄이 짱귀엽네 진짜
# 어흑...........너무귀여워.
# 취즈냥이 귀 왹 그래...?
# 너무 귀여워... 힐링,, 몽글🫶
# 탄이 츤데레 ㅋㅋ 강아지풀+생일축하 한다는 말 듣고 감동 먹었으면서 일부러 머리끈 질렸다고 던져버림 ㅋㅋㅋ 고맙다고 머리끈 주겠다고는 못하고 츤츤 거리는게 포인트 ㅋㅋㅋㅋ
# 고양이 양말냄새 맡는표정 너무 똑같아요!ㅋㅋㅋ 울냥이도 충격적인 냄새맡음 저리되요ㅋㅋㅋㅋ
# 댓글 34페이지 ================================================================================
#
# 고양이들 탄이 강아지풀 든 거 쫓아갈 때 꼬리 다 지팡이 모양인 거 귀엽다 신났구나 너희들!!
# 마루 구ㅏ여워ㅜㅜㅜㅜ
# 그 와중에 양말 너무 좋은거라 줄지 말지 고민 했다니 ㅋㅋㅋㅋㅋㅋ 마루 넘 귀여운거 아니냐고ㅠㅠㅠㅠㅠㅠ
# 언니 잘동안 마루는 혼자 멋진 모험을 하고왔네ㅎㅎ 기특해
# 고양이 이녀석 귀를 보아하니 땅콩 뗏구나?
# 아 너무 귀엽다..
# 근데 저 아이 중성화됬네..?
# 귀여워서 눈물 나
# 너무 기엽다..
# 탄이 강아지풀들고 고양이들이랑 담벼락 걷는 장면이랑 마루랑 언니랑 같이 자는 장면 배경화머ㅡㄴ으로 만들이주셨으면 좋겟다..... 너무너무 따수움...🥹🥹🥹
# 귀여워ㅜㅠㅠㅠㅠㅠㅠㅠㅠ
# 임주스씨 안추워요?
# 치즈냥이 표정 얼큰해ㅋㅋㅋㅋ큐ㅠㅠ입에 넣고 와랄라 하고싶다
# 작가님 이렇게 예쁜 작품 보여주셔서 정말 감사합니다....❤
# 건물...
# 댓글 35페이지 ================================================================================
#
# 귀엽다귀여워너무귀여워사랑스러워너무귀양워ㅜ
# 귀엽다...너무....
# 작가님 디테일 쩌는게 중성화한 길고양이는 왼쪽 귀 끝부분 살짝 잘려있다고 하는데 그걸 살리셨네요.. 리스펙
# 아 이번편 진짜 힐링 끝판왕이다ㅠㅠㅠㅠㅠㅠ울애기가 나 낮잠자는사이에 저랬을거생각하면 기특해서 눈물좔좔임
# 마루야 사랑해
# 탄이가 길고양이 출신이고 같이사는 엄마가 탄이 냥줍했나보네요
# 고양이 귀 잘린 거바...없나봐...
# 갯섬이 따땃해진다..
# 마루야 발닦고 들어가야지!!
# 고양이들이랑 탄이 짱귀엽다
# 탄이 개귀여워ㅠㅠㅠ
# 탄이 뒤로 쫓아가는 냥이들 꼬리 모양 합치면 하트네 ㅠ ♡
# 치즈냥이 짱귀여어.. 마루 머리 위에 얹혀가는거 개귀여움
# 치즈냥이 넘 귀엽당 ㅠㅠ 귀짤인디테일도 대박 ㅠ 계속 나오나요?
# 귀엽다 증맬
# 댓글 36페이지 ================================================================================
#
# 탄아..사랑해...ㅠㅠㅠㅠ 생일축하해 듣고 볼 빨개진 거 나만 본거야??! 그런거야??!???😭 이것 때문에 쿠키 지른다 해도 하나도 안 아까워 엉ㅇ엉엉ㅇ엉엉어어ㅗ
# 탄이네 집 외전 존버합니다탄이와 집사
# 탄이와 냥원정대
# 너무 귀엽고 사랑스러워서 코가 시큰 해 졌는데ㅋㅋ 또 뒤로 가면서 어린이들 선물 계획에 눈물이 쏙 말라버렸읍니다
# 이번화 정말 동화같다ㅠㅠㅠㅠㅠ 하면서 내려오는데 마지막에 급현실 선물무섭지ㅋㅋㅋㅋㅋㅋ
# 서율이가 안울거냐 장한거할때 마루가 조용히 따봉하는거 너무귀엽다ㅠㅠ
# 아 너무귀욥자나ㅠㅠㅠㅠㅠㅠㅠㅠ치즈냥이 미안하다고 부비부비하더니 물 무섭다고 마루 머리에 얹어져서는ㅠㅠ
# ㅠㅠ 강아지풀 받고 좋아하는 냥이들 소듕해😭
# ㅜㅜ진짜 너무 너무 깜직해🥲❤️
# 고양이들 강아지풀 장난감 엄~~~청 좋아합니다...
# ???:선물로 얼마나 대단한걸 받고싶길래?                         "동생이요"
# 냥이 중성화 하고 귀 잘린 거 웃프다
# 먐먐 고양이 귀 한쪽 잘린거는 무슨 표시지...? ㅠㅠ
# 고양이 발냄새 맡으면 입벌리고 이상한 표정으로 굳는데 그거 표현 현실리얼리즘 이네요
# 고양이들 한번씩 저리 고장난 표정지을때 너무웃김..우리첫째냥 둘째애기냥 화장실다녀온후 똥꾸핥아주다
# ㅇㅁㅇ 이표정으로 입벌리고 1분동안 넋나갔었는데
# 작가님 길고양이 디테일 정말 짱이세요🥲모르는 분들도 있는데 길고양이 중성화 사업 (TNR)
# 을 진행한 고양이들은 귀 한쪽을 조금 자르거든요..ㅠㅠ (중성화 구분때문에 표시 하는거에용)
# 아마 고양이 좋아하시는 분들 길고양이 사진에 귀 자세히 보면 중성화 되어있는 친구들을 볼 수 있을겁니다!
# 댓글 37페이지 ================================================================================
#
# 고양이들만 보면 주책맞게 눈물부터 걍 주륵주륵 흘리는 거 몇살이나 더 먹어야 고쳐지냐...
# 우우우우웅ㅜㅠㅠㅠㅜ귀여버..
# 아아아아ㅠㅜㅠㅠㅠㅠㅜㅜㅜㅜㅜㅜ 귀여워서 미칠거같다ㅜㅡㅠㅜㅜㅜㅠㅠㅠㅜㅠㅠㅠㅠㅠㅠ
# 귀여워ㅠㅠㅠㅠㅠㅠㅠ 진짜 귀엽다는말만 반복하는중 ㅠㅠㅠㅠ
# 고양이 개귀엽다..
# 나중되서 탄이랑 서율이랑 마루 사이에 두고 라이벌 되는거 아녀?
# 고앵이 넘무 기엽다ㅏ
# 월월!!!먇먀ㅑ먀ㅑ먀!!!
# 탄이랑 마루 너네....정체 숨길 생각 없는거지...그게 또 귀여워...ㅎ
# tnr해서 귀한쪽 잘려있는 디테일👍🏻👍🏻👍🏻
# 그래서 멱! 먀~가 무슨 얘기였어 얘들아ㅜㅜㅜㅜㅠㅜㅜㅜㅠㅜㅜㅠㅜㅜㅜ이모도 알려줘......
# 포브스가 선정한 올 해 최고의 히~일링물
# 의외로 별거 아닐거같아 원하는 선물
# 치즈냥이 중성화해서 귀 잘려있는 디테일 쩐당
# 아~귀여워
# 댓글 38페이지 ================================================================================
#
# 벼락치깈ㅋㅋㅋㅋㅋ
# 탄이가... 너무 귀엽슴다... 많이 보여주세요...
# 최고야ㅠㅠㅠㅠㅠㅠㅠㅠㅠ살랑살랑한거 보들보등한거 할때 동화같아ㅠㅠㅠ
#  작가님 이모티콘 만들어주세요 제발 작가님 이모티콘 만들어주세요 제발 작가님 이모티콘 만들어주세요 제발 작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발작가님 이모티콘 만들어주세요 제발
# 고양이는 ㅋㅌㅌㅋㅋㅋㅋ 이상한 냄새를 맡으면 더 자세히 맡으려고 본능적으로 입을 벌립니다 ㅠ
# 언니가 소중한거라고 하니까 동네를 싹다 잡아가지고 탄이한테 받아냈네ㅎㅎ 탄이는 강아지풀 받고 생일축하한다는 마루말에 감동받아서 머리끈 툭!던져주고ㅎㅎ 너무 귀여웡❤
# 마루야...사랑한다......
# 크아아아아악아아악 마루야 ㅠㅠㅠㅠㅠㅠㅠ
# 고양이 충격에 빠진 표정 ㅋㅋㅋㅋㅋㅋㅋ
# 냥이 중성화표시되어있는것도 섬세하네요
# 먁 ㅠㅠ🤍
# ㅋㅋㅋㅋㅋ치즈냥이 옆에따라붙어서 알려주는것도귀엽고 숨쉬듯이 배려하는 마루도귀엽고 아기고양이는그냥존재가귀엽고.. 늦었지만 생일축하해아기고양이..
# 너무 힐링돼...ㅡ..ㅡ 행복하다
# 꾸물꾸물 언니 옆으로 가는 거 너무 귀엽다 마루야ㅠㅠㅠㅠㅠㅠㅠㅠ 치즈냥이랑 헤어지기 전에 서로 웃는 것도 너무 사랑스러움ㅠㅠㅠㅠㅠ 마루는 강쥐 평생 연재해주세요ㅠㅠㅠㅠㅠㅠ
# 고양이 귀 잘려져 있네 중성화 했구나
# 댓글 39페이지 ================================================================================
#
# 넘넘 귀여워서 쿠키 막 구워드림~^^
# 살랑살랑 보들보들 흔들흔들~ 친구의 생일을 진심으로 축하해주는 마음이 딱 그렇네요
# 행복해
# 너무 귀여워..
# 재탕하다 알았는데 언니 낮잠 자기 전에 티셔츠 보면 분명 민무늬 초록 셔츠가 아니라 왕관 쓴 검은 고양이가 있는 티셔츠였어요 생일 떡밥이었군요!!
# 이 귀요미들..
# 진짜 다들 반팔ㅋㅋㅋ
# 진짜 작가님 사랑해요 ㅠ오래오래 연재해주세요.. ㅠㅡㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ하 애니로 나오면 진짜 맨날 볼듯 ㅠㅠㅠㅠㅠㅠ
# 하... 귀여워서 돌아가시겠다진짜
# 고양이 자극적인 냄세맡으면 짓는표정 귀엽
# 탄이 고양이 대장이냐곸 ㅋㅋ
# 헉 치즈냥이 설마 귀한쪽 끝 짤린거 길냥이 중성화 했다는 표시 묘사인가요...?! 디테일 대박...
# 앙대 그림너무 귀엽다구여 나죽어 ㅠㅠ
# 오늘의 명대사먁!
# 냐~
# 마루 자고있는 자세 너무 귀엽다ㅠㅠㅠㅠ
# 댓글 40페이지 ================================================================================
#
# 너무 이뻐ㅠㅠ♡ 괜찮아 누나도 이맘때쯤 울면안돼 들어 우리 같이 큰 거 바라자 누난 일단 연애^^♡
# 마음이 따땃....
# 힐링된다
# 넘기여워요..... 여태 본 것 중에 이 편이 최고 귀여운듯
# 나중에 탄이는 냥이 이런 웹툰도 내주면 좋겠다,,
# 하진짜너무귀엽다
# 치즈냥 귀여워....ㅠㅠ
# 진짜 단행본이 시급하다......ㅠㅠㅠㅠㅠㅠㅠ
# 진짜 보고있으면 너무 행복해지는 힐링 웹툰이다..
# 미치겠다...너무 귀여워...귀여워서 미치겠어..
# 우리랑 마루 얼굴 짜부되면서 꿀잠자는거 왜이렇게 귀엽고 사랑스럽냐ㅠㅠㅜ따수워
# 저 준호우리 묘한 키차이가 헤테로 외길 1n년 헤테로충을 미치게 함
# 힐링된다
# 행복해지는 웹툰 ㅠㅡㅠ
# 진짜 너무 사랑스러운 웹툰이다...
# 댓글 41페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 진짜 힐링 그잡채....
# 최고의 힐링 웹툰ㅠㅠ 사랑합니다
# 존나 기엽다 고양이가 세상을 구한다아아아아아아아
# 아 귀여워 행복해 몽글해!
# 마루가 철들었어 어느새 이렇게 훌쩍 커버린거지 너 진짜 기특하다 우와 대박 항상 언니를 뭐 캔따개로 보고 나 언제 놀아줘 이거해줘 이럴 줄 알았는데 내 기분은 좋아도 너무 빠르게 철든 거 아니니 어우 증말 이러면서 보다가 에라이 연말..
# 이번 화 두 번 봄... 몽글몽글
# 탄이 볼빨간컷 진짜ㅜㅜㅜㅜㅜ 세상에 졸귀야ㅜㅜㅜㅜㅜㅜ
# ㅠㅠ.. 귀여워 마루 볼 말랑모찌쫀득 할 거 같아ㅠㅠ.. 먁
# 이 시대 최고의 힐링만화다 .......... 하 마음이 몽글몽글해서 죽을거같아요
# 이번편 레전드 귀여움 한도초과..
# 으하하 너무너무 귀엽다 마루야~~사랑행💕💕💕
# 근데 왜 노란고양이 귀가 잘려있지
# 와 근데 진짜 작가님 못하는 장르가 있으심,,,??로맨스 ㅇ, 코미디 ㅇ, 스릴러(모죠의 일기에 가끔 나오는걸 참고) ㅇ, 힐링 ㅇ,,,,뭐지 이 웹툰 세계를 섭렵하려 우주에서 오셨나 사실 뿡따리샤바라쿵치따치가 작가님의 원래 이름이 아닌걸까
# 하루에정주행 한 오천번씩하는듯..
# 치즈냥이의 먀~는 아마 고마워였겠지......? 미치겠다
# 댓글 42페이지 ================================================================================
#
# 마루의 매력포인트1.  치즈냥이 물무서워 하니까 머리에 얹고 물웅덩이랑 계곡 건너는거.
# 2. 선물 찾는거 귀찮고 힘들텐데 힘든티 안 내고 치즈냥이랑 계속 같이 찾아다니는거.
# 3. 강아지풀 주면서 언니 머리끈 달라는 말이 먼저가 아니라 생일축하한다는 말  먼저 건네는거..감동ㅜ
# 마루야ㅜㅜㅜㅜ넘 따뜻하고 다정한거 아니니ㅜㅜㅜㅜ
#
# 멱! 먀~ 귀여워 죽겠음ㅋㅋㅋㅋㅋ 애기들아 싸우지 말고 친하게 지내
# 치즈냥이 양말냄새 맡고 플레멘 반응하는거 너무 웃기고 귀엽다ㅠㅠㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 역시 벼락치기의 민족...
# 치즈냥이 귀 누가 잘랏냐
# 힐링..
# 진짜 귀여워죽겠다
# 저기..작가님?...우리랑 주스는 언제까지 저래요? 썸은 타야죠ㅡㅡ
# 작가님 이런 몽글몽글한 연출 천재세요 증말..
# 언니 물건 돌려받으려고 노력하는 마루나강아지풀 받고 좋아하는 탄이나
# 선물받으려고 눈물참는 서율이나 귀엽다...😂
# 애기들 너무 귀여워..ㅠㅡㅠ
# 치즈고양이가 대신 고맙다고 해줬나바 기엽다
# 하ㅜ 걍 여기 캐릭터들 너무너무 귀여워서 힐링 제대로임ㅠㅠㅠㅠ
# 서율이 바람개비모양 가르마!! 왜 아무 언급업쬬??!!! ㅋㅋ 마루랑 친하게 지내죠 둘이 우정해♡♡
# 아 쉽알 분명 귀여운 웹툰인데 나는 왜이렇게 맨날 눙물을 흘리는 거야,,,
# 댓글 43페이지 ================================================================================
# 마루의 여행.. 귀여워..
# 오늘도 넘 따뜻하고 귀여운  ㅠㅠㅠㅠㅠㅠㅠㅠ 정말 작가님은 천재가 아닐까.. 문과끝판왕 모죠
# 그래서 그랫구나 ㅋㅋㅋㅋ귀여운것들
# 내용은 그냥 일상 평범물인데 애들 표정 하나하나가 너무 이뻐요 ㅠ  눈빛 만으로도 감정이 다 전달되는듯...
# 치즈 고양이 한쪽 귀가 좀 잘려있음. 날라간건가?
# 저 동화한편보고왔습니다 귀여운 마루와 사랑스러운 고양이의 이야기였습니다 너무 행복해서 입꼬리가 안 내려갑니다
# 탄아...축하받으니 조았구나???ㅠㅠㅠㅠㅠ애깅이들 사란해ㅐㅐ ㅠ
# 앜ㅋㅋㅋㅋㅋㅋㅋ 귀여워ㅠㅠ
# 여윽시..장난감...
# 고양이 귀 짤린거 보니 중성화했구만,,,,
# 아 진짜 힐링 그 자체
# 로맨스 이외의 웹툰에 돈 많이쓴건 이게 최초다
# 히히히힣  볼눌ㄹ린거 귀여워 ˙ᵕ˙
# 근데 저 길냥이 중성화 된 냥인가보다 귀끝이 뭉툭하네 디테일 진짜 미쳑딱
# 배댓 임주스씨에서 빵터졌다가 진짜 이름이 뭔지 기억 안남...임주스는 임주스야...
# 댓글 44페이지 ================================================================================
#
# 유일하게 꼬박꼬박 쿠키구워서 보는 웹툰❤️
# 💖🥺😳🥹🤍
# 진짜 엄마앞에서 대놓고 볼수잇는 이시대 최고의 개그와감동의 웹툰 1위
# 냐아~
# 볼 짜부된 마루 너무너무 너무너무너무너무너무 귀여워,,ㅠ
# 오늘도 귀여운 아가들💗
# 제발 이모티콘을 내주세요
# 마루, 고양이들 즐겁게 노는 거 너무 귀엽다... 얘들아 행복해라ㅠㅠ
# 양재천이니 얘들아?ㅜㅜㅜㅜ 거기가면 마루 만날 수 있는 거니??ㅠㅠㅠ
# 아 ㅋㅋㅋㅋ 너무 귀여워
# 너네 둘이 걸혼하는ㄱㅓ를 원한대(?)
# 치즈냥이 귀가.. ㅜㅜ
# ㅋㅋㅋㅋ서율이 인사하다가 데굴 구르는거 넘 귀엽... 애기들은 몸이 머리무게를 감당 못 할때가 종종 있는듯 ㅋㅋㅋ ㅜㅜ
# 엇 치즈고양이 중성화했나봐 귀에 표시 되어있네 디테일 대박
# 탄이 생일 축하한다고 하니까 볼 빨~개 지는 거 너무 앙큼한걸... 이번화 킬포 너무 많다... 꼬리 부푼 고양이와 철든 마루 ...
# 댓글 45페이지 ================================================================================
#
# 살랑살랑 보들보들 흔들흔들한거 강아지풀... 귀여브다 너무
# 가섬이 따듯해진다....
# 힐링그자체다🥹🥹
# 너무 사랑스러워 ㅜㅜ
# 이렇게까지 힐링이어도 되나요.... 근데 재미까지.....? 믿을 수 없어.......
# 고양이들 너무귀여워ㅋㅋㅋㅋㅋㅋ
# 치즈고양이 귀 한쪽 잘려있는건가.. ㅜㅜ 속상..
# 말 그대로 한편의 동화같은 이야기였다 자기 주인이 아끼는 물건을 가져간 고양이에게 그에 상응하는 물건으로 바꾸려 이곳저곳으로 돌아다닌 색감마저 따듯한 성인들을 위한 힐링물
# 어떻게 만화가 이렇게 한 화도 안 빼놓고 재밌고 따뜻할 수가 있냐
# 꺄ㅑㅑ 너무 귀여워 진짜로🥹🫶🥹🫶🫶🫶🫶🫶
# 강아지풀들고 뒤에 냥이들 따라가는 컷 힐링 그 잡채다 몽글몽글..❤️
# 귀어워ㅜㅜ
# 진짜 무조건 두번씩 보는 ㅠㅠ 웹툰
# 고양이파라 그런지 탄이 얘기도 너무 궁금!!!!!
# 이모티콘 만들어주세요
# 댓글 46페이지 ================================================================================
#
# ㅋㅋㅋㅋㅋㅋㅋㅋ 공포의 연말이다 ㅋㅋㅋㅋ
# 고양이 귀 한쪽 잘린거 보면 중성화한 고양인가부네
# 마루는 재밌는 냄새 나고 튼튼하고 물어뜯기 좋은거 갖고 싶대 우리야
# 너 언제까지.빈팔입을래
# 산타할아버지한테 선물 받으려고 일년동안 안울었는데 마루랑 율이 귀여워서 눈물흘려버림;;
# 임주스씨 맨날 반팔입어서 연말 겨울이라는게 존재 안 하는 세계관인줄...
# 하 진짜 힐링이다... 너무 귀엽고 웃겨
# 귀엽당
# 고양이 친구 고자구나...ㅠㅠ
# 탄이 짱기여미
# 살랑살랑 보들보들 흔들흔들그거 마루 꼬리잔아 🥲😭😇
# 생일 축하해 ㅠㅠㅠㅠㅠㅠㅠ 생일도 아닌데 눈물 나잉
# 귀여운거 더하기 귀여운거 = 사망😇
# 연탄아 생일 축하해
# 치즈고양이 귀 한쪽 약간 잘려진거 보니 중성화끝낸 길고양이일까..? 탄이도 원래 길고양이였다가 지금의 주인이 발견하고 키우고있는걸까
# 댓글 47페이지 ================================================================================
#
# 사랑스러운 마루 ❤️
# 탄이 대장냥이일 때 고생 많았을 거 같음 ㅜㅜㅋㅋ 다 같이 줄 지어 담 위에 걸어가는데 혼자 꼬리 끝 뚝 잘려있고ㅜㅜ.. 그랬던 탄이가 유치원 보내주는 집사랑 어떻게 만났는지 너무너무너무 궁금해요
# 살랑살랑 보들보들 흔들흔들 나오는데 자꾸 갈대 나오는데 마루 눈길도 안주는거 웃김
# 탄이..마루한테 왜구래 ㅜ..
# 축구 보고 아픈 마음 마루 보고 힐링,,,🥹
# 치즈 고양이가 마지막에 먀~ 하면서 고맙다고 한걸까 하 너무나 힐링웹툰이야 증말
# 너무 구이여영버
# 이 만화를 보는 저도 오늘이 생일이 되었습니다... 보기만해도 행복한 만화... ^^
# 치즈냥이 우는소리 진짜 다채롭네..
# 고양이 중성화되어있나보네용 귀가 조금 잘린걸보니...혹시 탄이 엄마랑 관련있을까여...?
# 치즈고양이 자세히보니 한쪽 귀 잘렸네ㅠㅠ....어떡해ㅠㅠ 너무 아픈 사연은 아니면 좋겠다 밖에 엄청 추운데 길냥이들 길멍이들ㅠㅠ맘아픔
# 마루 볼 눌린거 너무 귀엽다..
# 꼬리 살짝 잘린거 머예요 tnr을 요렇게 표현하신건가?!
# 길냥이들 중성화 수술 했나봐요 ㅠㅠ 귀 한쪽 짤려있는것도 현실고증이면서 안쓰러우면서 또 귀엽네요 :) ㅠㅠ
# 내 유일한 낙 ... 힐링웹툰... 왜 일주일에 한번인거죠 일주일 내내 올려줘요 진짜 맨날보고싶어 미리보기가 더 필요해 .....
# 댓글 48페이지 ================================================================================
#
# 아 길고양이 중성화수술했나봐ㅋㅋㅋㅋㅋㅋ 귀 조금 잘려져있는거봐ㅋㅋㅋㅋ큐ㅠㅠㅠ
# ㅋㅋㅋㅋㅋ 안 울어 ! 하는 거 보고바로 크리스마스 생각났는데 ㅜ ㅜ ㅜ
# 아 진짜 귀엽다 하 ㅇ<-< .........
# 와 역대급 힐링편..... 무슨 독립영화 한 편 본 것 같음 선물 찾으러 다니는 장면들 영상으로 간직하고 싶다ㅠㅠㅠㅠㅠㅠ 따뜻해
# 크리스마스에 눈이 오게 해주세요 이런거...커다란 고기집에 들어가서 파먹게 해주세요 이런거?
# 너무 따숩다........ 너무 조아....
# 마루 볼 밀리는 거 너무 귀여워너 진짜 애기야ㅜㅜ
# 저만 마루가 👍할때 법규 날린줄 알고 다시 봤나요
# 서율이 머리가 무거워서 넘어진거야? 진짜 귀엽가
# 솔직한 우리 마루 너무 귀엽구 대장고양이친구 짱 귀엽다
# 아 마루 서율이 안 운다니까 엄지척 날려주네 ㅋㄹㄱㅋㅋㄱㄱㅋㅋㄱㅋㄱㅋㅋㅋㅋㅋㅋㅋ
# ㅋㅋㅋㅋㅋㅋㅋ겹다기여어ㅓㅠ
# 마루야 서율아 어떤 뚱뚱하고 수염 난 할아버지가 너희를 빨간 가방에 넣으려 해도 놀라지 마 :) 내가 크리스마스 선물로 너네를 말했거든 :)
# 난 언니한테 볼 꾸욱 눌린 마루가 너무 좋아...ㅠㅠ
# 마루는 히히 별건 아니고~ 하면서 줄줄 말할거같틈
# 으아 쿠키 결국 여기까지 질러버렸다 흑
# 댓글 49페이지 ================================================================================
#
# 우리 마루 냄새 고약한 양말이나 아주 튼튼한 공을 받고싶은건가?? 우리 마루 그런거 좋아하는데..
# 사랑스러운 웹툰 최고의 웹툰 내 맘 속 일 등 이 야 ,,,
# 치즈냥이 중성화 되어있다ㅠ
# 탄아!!! 우리도 수백번 말해줄게 우리 아기고양이 탄아 생일축하해~!!!!!!
# 아너무귀여워 ㅠㅠㅠㅠㅠㅠㅠ 마루 귀엽고 치즈냥이도귀엽고 탄이도귀엽고 서율이도 귀여워 ㅠㅠㅠㅠ 흐아 힐링그자체야
# 너무좋나뇨 ㅎㅎ
# 마루가 빨래 다 흘리는데요 ㅠㅠ
# 양말 냄새맡고 충격받은 치즈냥이 얼굴 너무 좋다.. 폰배경화면하고싶음ㅠ
# 마루 볼 찌부 넘 귀엽자나ㅠㅠㅠㅠㅠ
# 저기 치즈냥이 중성화 됐나바 귀 한쪽이 반이야 디테일👍👍
# 치즈냥이 귀 잘려있네
# 언니한테 치대서 얼굴 구겨지는 마루도 킬링포인트♡
# 비밀이라고 말하면서 안겨있는 마루 너무 귀엽고 사랑스럽고 포근하고 달달하고 몽글하고 따뜻하고 부드럽고 훈훈하고 행복해 ㅠㅠㅠㅠㅠ
# 지금 우리딸 상태랑 똑같아서 바로 크리스마스!!! 를 외친 딸 엄마...... 8ㅁ8 첫째딸이 뭐 갖다달라고 할까 라고 물어보니까 곧 태어날 둘째딸 딸랑이를 가져다 달래서 감동했지만 바로 내껀 티니핑스쿨 이라고 붙여서 감동이 조금 와장창했어요... ^__ㅠ
# 치즈냥 귀 잘못그린줄 알았는데 중성화해서 귀짤린거였구나
# 댓글 50페이지 ================================================================================
#
# 수많은 갈대들 두고 강아지풀 들고가는거 너무 귀여워ㅋㅋㅋㅋㅋ
# 아아아 너무 귀엽다얘들아 뭐갖구싶니...언니/누나 한테 다 말해봐
# 전부는 아니어도 하나씩은 좋아하는거로 꼬옥 사줄게ㅠㅠ
# 아 물론 산타할아버지가 주는거야 언니가 할아버지한테 편지써준다구...^^
# 으아아앙 힐링된다ㅠㅠ
# 모죠님께서 아뢰시길 이제부터 강아지풀은 강아지에게 한정되면안됨 그냥 뽐뽐털뭉치들소유권식물로변경해라 이것저것보장해라
# 크리스마스엔 쥬스씨네 패딩 한 벌 사드려야겠어요...
# 임주스씨 안 추으신가요 감기걸리면 안되는게 아니네 이번에 우리씨가 챙겨주면 되니까 사실 이 모든게 빅픽쳐였다
# 강아지풀주면서 생일축하해ㅠㅠㅠㅠㅠㅠ...너무 너무 귀엽다...마루야...그리고 강아지풀 들고 고양이들이랑 담장 타면서 신나게 걸어가는 탄이까지...완벽했다...
# 와 진짜 오늘 마루도..고양이들도 다들 하찮동글맬렁한게 넘 귀여웠고 삐죽삐죽 탄이도 선물 좋아하는 마음 숨기다가 기뻐서 담장 위 고양이들 데리고 달려가는 거 넘 귀여웠다..ㅠㅠㅠㅠ
#  마루는 강쥐는 진짜 애니매이션화 되어서만화 원작 이었던 짱구처럼 극장판으로도 나왔으면 좋겠음..ㅠㅠㅠㅠ
# 그런데서 특별 스토리로 마루와 탄이가 투톱 주인공으로 나와서 같이 힘을 합쳐 주변 인물들과 함께 각자의 동물 본능..?으로 함께 위기를 헤쳐 나가게 나와도 정말 좋을 것 같음 ㅋㅋㅋ
# 그럼 한편 뚝딱인데 벌써부터 포스터가 막 상상되는 것 같은..ㅋㅋㅋㅋ
# 이참에 우리나라도 짱구처럼 국민 애니?가 나왔으면 좋겠다 ㅋㅋㅋ큐ㅠㅠㅠ안녕자두야처럼 만이라도..ㅠㅠㅠㅠㅠ
# 퓨ㅠㅠ 저거 양말같은거 냄새 맡으면 고양이 입벌리고 벙찌는 행동 ㅋㅋㅋㅋ 표현이 싱크로율 100% 허망한 눈동자가 너무 웃겨..
# 고양이귀컷땨먀마움아프
# 나만 치즈냥이 귀 한쪽 신경쓰여ㅠㅠㅠ?? 애깅ㅠㅠ
# 오늘도 힐링된다♡
# 아ㅠㅠㅠ양말냄새 맡은 치즈냥이 표정 뭔지 알아서 너무 귀여움ㅋㅋㅋㅋㅋㅋ쿠ㅜㅜㅜ오늘 내용 진짜 간질간질하다
# 강아지들은 주인 양말을 저래서 좋아하는거였냐ㅋㅋㅋ
# 오늘 편 너무 행복하고 따뜻하고 ㅠㅠ 아기들아 사랑해
# 댓글 51페이지 ================================================================================
#
# 댓글 페이지 개수: 9
#
# 탄아 생일 축하해 .ᐟ.ᐟ.ᐟ .ᐟ.ᐟ.ᐟ .ᐟ.ᐟ.ᐟ ♥
# 마루가 점점 말을 유창하게 하는것같음!!! 마루 잘크고있구나!!!!
# 고양이 귀가 잘렸다는건 길고양이들 중성화 표시에요작가님 섬세한 표현 너무 멋쪄 요오~!❤️
# 아기들 너무귀엽다 ㅋㅋㅋ탄이 팔찌 야무지게 끼고잇는거보고 행복해짐
# 동생!!!!!!!!!동생!!!!!!!!!!!!!!!!!!!!!!
# 이번화 킬링포인트1. 선물이랑 생일축하받고 귀여운 얼굴된 탄이
# 2. 씩씩한 마루
# 3. 착한어린이 벼락치기하는 마루랑 율이
# + 멱멕 등 사실적인 치즈냥이 울음소리 ㅋㅋㅋ큐ㅠㅠㅠ
#
# 하 일주일의 행복이네요 정말
# 고양이는 안키워봤지만 탄이 보면서 확실히 마루랑다른 매력이 있다는걸 느낀다
# 꼬리펑 너무 귀엽다...
# 고양이 귀한쪽이 잘린거까지 표현해주실줄이야...디테일 댑악..(고양이 귀한쪽이 잘려있는건 중성화가 되어있다는 암묵적인 뜻입니다.)
# 탄이 생일축하한다는 말 듣고 얼굴 발그레해지는거 개귀여워!!!!!!!!!!!!!!!!!!
# 밝은 미소 뒤에 감추어진 속내......
# =͟͟͞͞귀=͟͟͞͞여=͟͟͞͞워 =͟͟͞͞귀=͟͟͞͞여=͟͟͞͞워 =͟͟͞͞귀=͟͟͞͞여=͟͟͞͞워  ​... 착해... 야옹이 물 무서워하니까 머리에 얹어주는 마루... 귀엽고 착해...
# 탄아!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!연탄!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 생일!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 축하해!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 누나가!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 너많이!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 아끼고!!!!!!!!!!!!!!!! 사랑한다!!!!!!!!!!!!!!!
# 선물!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 주고싶은데!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 누나가!!!!!!!!!!! 돈이없어 제기랄!!!!!!!!!!!! 미안!!!!!!!!!!!!!!!!!!!
# (앞집엽집뒷집윗집아랫집(지하주차장)죄송합니다 야밤에 소리질러서.. 그치만 타니타니연타니쨩이 너무 귀여웠어요..)
# 나는 안울어도 선물 못받는 나이지만... 마루랑 서율이 저렇게 좋아하는거보니 나도 좋다 이말이야...
# 머임? 둘이사귐? 왤캐 자연스러움? 결혼함?
# 댓글 52페이지 ================================================================================
#
# 마루 큰 장면은 아니지만 작게작게 누군가를 배려하는 장면들 너무 이뻐요ㅜㅠ 치즈 물 무서워하니 본인 머리에 올리고 가는것봐ㅠㅠ 마루 은근히 이런 행동이 많고 사랑스러워ㅠㅠ
# 탄이는.. 정말 고양이인걸 숨길 생각이 1도 없구나? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 냅다 강아지풀 들고 고양이 원정대 만드는거 귀여워 죽겠네
# 마루 볼 눌린거 개귀여워ㅠㅠㅠㅠ
# 치즈냥 ㅠ중성화 해서 귀 한쪽 잘린디테일봐 ㅠㅠ
# 근데 치즈고냥이 오른쪽 귀 살짝 잘린거 중성화 수술 자국 맞나요? tnr 수술하면 귀를 살짝 잘라서 표시(?)를 한다던데
# 약간 마루가 동생 갖고 싶어할 듯
# 자연스럽게 들어오는 임주스... 연말 싫어하지만 그 누구보다 애들 크리스마스를 열심히 챙겨줄거 같은 임주스... 난...난...너무 행복해...
# 탄이 너무 귀엽다 ,, 좋은데 싫은 척 ,,
# 역시 목적이 있었군 ,,
# 너무 귀여워 .... 시험기간에 단비같은 몽글함... 최고네..
# 몀며며 맹매매ㅠㅠㅠㅠㅠㅠㅠ 사랑한다 마루&탄이&고영들ㅠ ㅋ ㅋ ㅋ 얘들아 너네 크리스마스라고 소소한거 바랄거면서 잔뜩 힘 들어간거 너무 귀여운거 아니냐ㅜ_ㅜ!!! 빨리 언니 형한테 착한 일 하라구
# 산타 벼락치깈ㅋㅋㅋㅋㅋㅋㅋ
# 치즈냥 중성화수술 했구나!
# 너무아름다운웹툰이야.......
# 이젠 임주스씨랑 우리랑 같이 있으면 광대가 올라가는 로맨스처돌이가됨
# 댓글 53페이지 ================================================================================
#
# ㅋㅋㅋㅋㅋㅋㅋ ㄱ아놔 양말냄새맡은 고양이 ㅋㅋㅋ ㄱ ㄱ ㄱ 귀여워 미챠
# 인사하다 꿍하는 거 봐... 아기야 ...
# 마루랑 서율이.. 마음껏 울어.. 산타할아버지는 언니가 처리할게.
# 힐링..ㅠ
# 오늘은 그림책 한 편 읽은듯 기분이 몽실몽실해지네요🤍
# ㅋㅋㅋ시험 7일전에 웹툰보고 공부 5분바께 안하는 나와 비슷하구나 벼락치깈ㅋㅋ
# 귀여워.귀여워.너무귀여워.탄이귀여워.천사고양이.
# 마지막 먁의 의미가 넘모 궁금한데
# 우리랑 임주스씨 걍 부모같은데ㅋㅋㅋㅋㅋㅋ
# 좋아하는것들 보면 ㄹㅇ 말 못하는 개랑 고양이들은 친해지긴 어렵나보다ㅋㅋㅋㅋㅋ
# 갱얼쥐한테 좋은 거랑 고먐미한테 좋은 거랑 이렇게 달라도 되는거임?? 하 너무 귀여워
# 냄새맡고 털 펑 터진거봐ㅜㅜ
# 우리애기들 고양이들 ㅜㅜㅜㅠㅜㅜㅜㅠㅠ 사랑해ㅜㅜㅜㅜㅜㅜㅜㅜㅠㅠ
# 오늘 만화 진짜 동화같네요 ㅜㅜ 따숩다
# 아니....나도 10점 줬는데.....내가 별점을 누루자마자 별점이 떨어졌어.....나 10점 눌렀는데........ 왜 내가 나쁜짓을 한 것 같지...........왜........
# 댓글 54페이지 ================================================================================
#
# 그럼 우리하고 임주스씨 같이 크리스마스 보내는 거야..?
# 아ㅠㅠㅠ 생일축하해 하는 마루도 귀엽고 열심히 컨펌해주는 치즈냥이도 귀엽고 츤츤대면서 머리끈 돌려주는 탄이도 귀엽고 울음 참는 서율이도 귀엽고 연말에 반팔 입고 있는 임주스씨도 귀엽고 다 귀엽다 증맬루ㅠㅠㅠㅠㅠ
# 이번 회차는 동화 한 편 봤다 아 잘 쓰인 쿠키였다
# 벼락치기는 역시 1일 전에...
# 고양이 귀끝 살짝 잘려있는거 길냥이들 중성화 표신가요?.?
# 마음이 몽글몽글해짐,,, 따수버...
# 마루가 좋아할 만한 선물: 언니 발 꼬린내 나는 양말, 너덜너덜해진 침냄새 나는 애착인형, 이불 속에 숨겨놓기 좋은 개껌, 멋진 나무막대기
# 내가 이만화에서 삼각관계를 먹을줄 몰랐지...탄 서율 둘다 마루꺼해
# 나도 오늘부터 벼락치기 착한어른 간다
# 근데 마루는 무슨 옷을 입은 건가요? 장갑까지 달린 쫄쫄인가?개신기하ㅔ네
# ㅠㅠㅠㅠㅠ진짜 눈물나게 따스한 웹툰이야,,,저는 이렇게 따수운걸 보면 주책맞게 눈물부터 나는지 모르겠어여ㅠㅠㅠㅠ 자까님 감사합니다,,🥺🥺 올해 23살로 살아오면서 마루 웹툰 찾은게 젤 잘한 일이예여😭😭😭😭😭😭😭😭
# 고양이가 물 못건너니까 머리에 얹고간거 봐ㅠㅠ 마루 착해ㅠㅠ
# 생일이라 생일선물 받고있던 탄이도.... 우리 머리끈 찾아주려고 요리조리 돌아다닌 마루도....... 너무너무너무귀여워서 빨아묵고싶다현세대 최고의 힐링물
# 길냥이들 중성화 시킬때 귀한쪽 끝 자른다는데 마루 도와준 저 고양이도 귀 한쪽끝이 잘려있네유..안쓰럽ㅠ
# 빨래 다시 헝클어진거봐ㅋㅋㅋㅌㅌㅌㅋㅋㅋㅌㅌㅌ
# 댓글 55페이지 ================================================================================
# 서율이 안 운다니까 마루가 따봉 날리는 거 졸귀ㅠㅠㅠ
# 탄이 말은 저렇게해도 뒷모습 너무 신나보임ㅠㅋㅋㅋ이렇게 귀여워도되냐구요...ㅠㅠ아가들...
# 오늘 완전 힐링 끝판왕이다ㅜ
# 아어떡해... 너무 귀여워서 미치겟다.... 광대가 안내려옴
# 그치 착한일도 벼락치야
# 마루랑 고앵이 길 떠나는거 너무 따숩구..
# 귀엽고 사랑스러워서 심장이 아파 아 진짜 아픈데;;;
# 아기들의 벼락치기식 바른 태도가 너무 귀여븜ㅠ
# 너무너무너무귀여워><
# 생일 축하한다는 말에 감동받은거 진짜 귀엽다
# 진짜 넘 따숩고 일상적이고 평화러운데 개웃겨 ㅠ 진짜 짱이에요
# 이번화 약간 어렸을 때 읽은 동화책 느낌 나서 좋다...ㅠㅠ
# 하....마루랑 치즈고양이 같이다니면서 선물 열심히 찾는고 진짜 넘귀여워 치즈냥이 컨펌해주고 마루가 치즈냥이 물웅덩이 건너는거 도와주고 그냥 둘다 한입에 삼켜버려
# 참나... 둘이 대화하는거 마음따듯해미치갯내
# 고양이 귀 잘려있는거 맴이 아퍼ㅠㅠ
# 댓글 56페이지 ================================================================================
#
# 애옹이한테 고맙다고 하는더 너무 귀엽고 포근하고 푹닥하고...이리온
# 근데 올해겨울 너무늦게오긴했어....주스씨 저도 얼마전까진 반팔이었어요....
# 마루가 내 월드컵이다..
# 어린이들은 일년에 정말 많은일이 있구나!
# 탄이 강아지가 갖고 온 강아지풀 가지고 노는 거 넘 귀엽다...
# 하..강아지 풀 대장ㅠㅠ 너무 행복해서 눈물남.. .🥲
# 우리가 마루 기특해할때 뒤에 써있는 글자 궁금하당...
# 분량 뭐임
# 🐈‍⬛🐈🐈🐈
# 아 탄이 눈 땡그래져서 강아지풀 쳐다보는데 넘 귀여워요ㅜㅜㅜㅜ진짜 마루만 오매불망 기다리는데 최곱니다.. 마루 보고 있으면 행복해요평생 연재해주세요 작가님🥹
# 아어떡해?ㅇ임준호너무오랜만에등장ㅇㅎ아니이게대체몇주만이람ㅇㄴㅠ나울어
# 바로 윗집 올라오는거라지만 반팔은 너무하잖아요 임주스씨ㅠ 안 춥나?
# 착한짓 벼락치기ㅋㅋㅋㅋㅋㅋ
# 우리랑 마루랑 포옥 껴안고 자는 거 너무 귀엽다... ㅜ
# 연탄아 이제 울 마루에게 잘해주렴 이 아저씨가 기대하고 있거든^^
# 댓글 57페이지 ================================================================================
#
# 근데 할로윈때부터 진짜 이정도면 주스씨랑 결혼한거 아님?..같이 애들 분장 고민하고 선물 생각하고..나 애기 때 우리 엄마아빠가 하던 대화같은데ㅠㅠㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 고양이 양말냄새맡고 꼬리부푼거 넘기여븜ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ
# 🐱 🙀 😻 😺 😾 😸
# 아 마루랑 서율이 댕기여워 죽겠구만
# 너무 몽글몽글해.. 한컷한컷 안 귀여운 컷이 없어.. 미친 웹툰이야.. 사랑스러워.. 동물친구들 사람들 다 너무 귀엽다고..
# 넘나 귀여운 것들. 입가에 미소가 떠나질 않음. ㅋ작가님 다시 봤음. ^^*
# 저 침대 근처에 가면 따끈하고 포근한 냄새 날 것 같음 아 커여워
# 몽글몽글 따뜻하다...
# 아 마루야 ㅋㅎㅋㅎㅋㅎㅋㅎㅋㅎㅋㅎㅋ 귀엽고 기특하고ㅠㅠㅠㅠㅠ 김탄? 감탄? 연탄이던가 여튼 고양이친구도 너무 귀여워ㅠㅠㅠㅠ 마루가 헐이래 헐,,,,
# 일단 우리 언니의 크리스마스 선물은 임주스씨 되시겠다
# 브라질전 제발 이겼으면
# 그니까 마루랑 서율이 생각 이거지 지금... 역시 한국인이다
# 산타 할아버지가 벼락치기형 착한아이 좋아할 거라 생각함?
# ㄴ 알빠임?
# 너무귀엽다 ㅜ
# 치즈냥의 먁! 멱! 먀~ 🫶
# 아놔 주스씨 안추워요...?ㅋㅋㅋㅋㅋ
# 댓글 58페이지 ================================================================================
#
# 탄이... 짱 보들보들 하고 팔랑거리는 선물보단 생일 축하한단 말에 더 감동 받는 거 너무 순수하고 귀엽다... ㅜㅜㅜ 생일 축하한다니까 머리끈 바로 돌려주는 것 좀 봐... 이 순딩이
# 아뿔싸
# 진짜 별거 아닐거같다...
# 주스야 안춥냐
# 하 ㅋㅋㅋ 머리끈 찾아 주고 뿌듯해서 입꼬리 쓱 올라간 마루 귀여워...... ㅠㅠㅠㅠ
# 따숩...
# 임주스 지혼자 여름이여... 따숩게 입고댕겨라
# 나 주스 보고싶었네...
# 으어 가슴이 몽글몽글 ㅎㅅㅎ
# 오늘따라 진짜 몽글몽글하고 동심 느껴지고... 햇볕에 잘 말린 이불 같은 느낌 나고
# 선물 나도 기대된다.어떤 엉뚱깽뚱 순수한 걸 기대하고 있을까나 ㅎ
# 탄이 새침 떠는거 귀여워 죽네 ㅋㅋㅋㅋㅋ ㅠㅠ
# 탄아....친구 얼굴에다 물건 던지는거 아니에요......😇
# 리본 머리끈 마루 얼굴에 텁. 하고 붙은 거 너무 웃기다
# 서율이 푸욱 몸 숙여서 열심히 인사하다가 냅다 넘어져버린 거 실화야?? 그래놓고 눈 울망울망해서 계란후라이 눈 되어놓고서는 산타할아버지 생각해서 꾸욱 참은거 실화냐고 하... ㅠㅠ 서율이랑 마루는 전설이다...
# 댓글 59페이지 ================================================================================
#
# 아 탄이 너무 귀여워..
# 살랑살랑.. 보들보들.. 마음이 몽골몽골 해지네요
# 냥이랑 마루랑 햇살 가득하고 몽글몽글한 하루 너무 마음이 좋다...
# 모죠님 집사라 그런지 고장난 고영표정 넘 잘 그리시네요
# 뭐긴뭐야 우리 언니의 사랑이겠지~~~
# 고양이가 물 무서워하니까 마루가 머리로 고양이 이고 가는 거 귀엽다..
# 마루는 점점 더 사랑스러워진다~~~♡♡♡
# ㅇㄴ 중성화냥이 왜케 띨빵하게 생김? ㄴㅁ귀엽다진짜
# 하..마루가 생일 축하한다니까 탄이 볼 묘하게 발그레해짐...기쁜가봐...이 아기들에게 평생 기쁜 일, 행복한 일만 있기를ㅠㅠ
# 마루 너무 사랑스럽따 . . ㅜㅠ
# 마루 안우는 서율이 보고 따봉 👍👍
# 탄마루 우정을 응원한다
# 마루야 아이고 요 아기가.. 고양이 물 싫어한다고 머리에 얹어 가고.. 빨래도 도와주고.. 아이고 아이고 할미는 인자 눈 감아도 쓰겄다. 우리 마루 다 커부렀다 아이고..
# 애들이 너무 귀여워서 울어버렷는데 나 선물 못받으면어쩌지
# 살랑살랑 보들보들 반복하는거 진짜 평화로운 짱구 감성이라고 해야하나 막 막 있잖아... 아무튼 동심 생기네...
# 댓글 60페이지 ================================================================================
#
# 살랑살랑하고 보들보들한거... 마루자나... 선물 그잡채🥹
# 마음이 너무 따땃하다,,
# 세상에... 생일이라 고양이들이 선물 조공하는거였나봐 너무 귀엽구 소중하다 진짜 생일 축하해줬다고 좋아하는 탄이 하 너무 귀엽네.............
# 너무 귀여워요....
# 산타선물받을라고 벼락치깈ㅋㅋㅋㅋㅋㅋ
# 크리스마스인데 주스씨랑 우리씨 데이트 하게 애기들은 내가 데려갈게...
# 탄이 시점 이야기도 듣고 싶네요ㅠㅠ
# 탄이두 자주나왔으면 🫶🏻
# 마루 뿌듯한표정으로 집드러와서 자다깬척 꼬물꼬물 이불로 들어가는거 너무 사랑스러워...............ㅁㅊ
# 그러취.... 추석지나면 사탕줘야하고 사탕주고 나면 빼빼로 줘야하고 빼빼로 주면 이제 금방 크리스마스고 이줴 크리스마스 지나먄 설날이거 설말지나면 어린이 ㄴㅏㄹ 헉헉
# 너무 포근포근해 너무 따수워... 행복해... 사랑해...
# 애들이 너무 귀여워서 뽀뽀해버리고 싶음😍😍
# 치져냥이 귀 저렇게 된건 중성화했다는 의미에서 병원에허 귀 커팅하는겁니다.. 저렇게 표시 안하면 중성화가 필요한 스트릿캣인줄 알고 또 병원 델꼬가요
# 허엉 허어엉 탄이생일축하해
# 준호네 난방 잘 되나보다
# 댓글 61페이지 ================================================================================
#
# 댓글 페이지 개수: 3
#
# 그와중에 강아지풀 챙겨가는거 귀여워 ㅋㅋㅋㅋㅋ
# 10점 만점에 삼만 오천점짜리 웹툰이다 정말... 마음이 넘 몽글몽글해짐🫶
# 마루 침대 위로 올라와서 옆에 눕는거 완전 울집 댕댕이랑 똑같다🥹
# 너무귀여워 마루아기야사랑헤
# 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 마루귀여워 엉엉... 나도 마루....
# 벼락치기의 민족..
# 근데 준호는 겨울인데도 반팔을 입고있네 ㅋㅋㅋㅋㅋ
# 얘들아 이모 잘 울지..? 이모가 다 울테니까 이모 선물까지 너희가 다 가져가걸아..
# 울음 참는 서율이한테 따봉 날리는 마루 ㅋㅋㅋㅋㅋㅋㅋㅋ 너무 귀여워!!!
# 너무기여워서 눈물이난다...
# ㅋㅋㅋㅋㅋ 벼락치기 ㅈㄴ 웃김 ㅜㅜㅜ
# 마루랑 서율이도 벼락치기 하네... 방학숙제마냥..
# 애기들 너무 귀여워서 울거같애.... 아 너무 진심...나울어요 진짜 울어
# 우리랑 임주스씨 너무나 신혼부부vibe..
# 아ㅋㅋ 우리 학생들은 시험에 벼락치기 하는데 우리 귀요미들은 산타할아버지가 주시는 선물에 올인하는구나ㅠㅠ 귀여미들ㅠㅠ
# 댓글 62페이지 ================================================================================
#
# 아악!!! 너무 귀여워탄이도 강아지 풀에 휘둘렸으면서 아닌척 졸귀탱 하 저 다른 냥이들 데리고 위풍당당하게 걷는거 완전 머리 치켜들고 걷는 고양이 그 잡채ㅠㅠㅠㅠ
# 생각해보니 풀도 강아지풀이야ㅠㅠㅠ 이 귀여운 겅아지 고양이들아악ㅠㅠ 서율이도
# 옷 다 흘리는 거 너무 규ㅣ여워서 눈물 흘리는 중
# 하진짜마루랑탄이넘귀여워애기들
# 제 크리스마스 선물은 연재 2편으로 부탁드립니다!
# 열심힌 하는데 빨래 갠거 다.. 어그러졌는걸...? 우리야 알고있어?!?!?!!??ㅋㅋㅋㅋㅋㅋㅋㅋ
# 탄이 최강고양이
# 너무 귀엽고 보면 마음이 깨끗해져요 ㅠ ㅠ기엽당
# 아ㅜㅜ 마루 엄지척 너무 사랑스럽다....
# 너무귀여워미칠것같애ㅠ이것만기다렷어
# 아 치즈고양이 물 무서워해서 마루가 머리에 얹고가는 거 너무 귀엽다..
# 아 귀엽다 귀여워 사랑해 마루야... ㅠ
# 마루 입에 넣고 와앙 하고 싶다 ㅠ
# 고양이들 꼬리 물음표인거 넘  귀엽다 ㅠㅠ
# 하 마루야 오늘도 사랑해,,,
# ㅋ ㅋ ㅋ미리보기가 너무 많아서 이거 무료로 풀릴땐 크리스마스 다 지나있겠어요~~~
# 댓글 63페이지 ================================================================================
#
# 우리 탄이 대장고양이네ㅠ 넘귀엽따
# 마루 도와준 치즈냥이 귀 잘린거보니 원래 집냥이었는데 버려진듯ㅠㅠ
# 하 탄아 생일 축하해 최강 냥이..
# 탄이생일과 애기들 크리스마스 선물 저희가 드리겠습니다!!
# 질렸어 하는 겈ㅋㅋㅋㅋ 고양이 츤츤...
# 으앙귀오워
# 강쥐랑 고양이 차이 나는거 너무 기엽자나ㅠ
# 댓글 64페이지 ================================================================================
